# %%
#SET-B
class Character:
  def __init__(self,name,hp,characterType):
    self.name = name
    self.hp = hp
    self.characterType = characterType
  
  def getMoves(self):
    return "Basic move: " + "Quick Attack"
 
  def __str__(self):
    return "Name: " + self.name + " Hit points: " + str(self.hp) + " Character Type: " + self.characterType

#solution

class AdvanceZCharacter(Character):
  def __init__(self,name,characterType,appearance):
    super().__init__(name,characterType)
    self.appearance = appearance

  def createCharacter(self,name,finisher):
      self.name = name
      self.finisher = finisher
      print("Unknown Character Detected")
  
  def getMoves(self,basic_m):
      self.basic_m=basic_m
      return "Basic move: " + "Quick Attack"
 
  def __str__(self):
    return "Name: " + self.name + " Hit points: " + str(self.hp) + " Character Type: " + self.characterType
    + " Appearance " + str(self.appearance) 
    + "Basic move:  " + str(self.basic.m) 
    
class NewCharacter(Character):
   def __init__(self,name):
    self.name=name
   def __add__(self.name+self.name):
     return "Name: " + self.name + " Hit points: " + str(self.hp) + " Character Type: " + self.characterType
     + 
 

      #return "Name: " + self.name + "Character Type : " + str( Hybrid ) + " Appearance: " + self.appearance



 
#Driver Code
Tien = AdvanceZCharacter.createCharacter('Tien',['Tri beam'])
print(Tien)
print(Tien.getMoves())
print('*****************')
Roshi = AdvanceZCharacter('Roshi',150,'Human','old',['Kamehameha'])
print(Roshi)
print('*****************')
Goku = AdvanceZCharacter('Goku',1050,'Saiyan','Young',['Kamehameha','Spirit Bomb'])
Freiza = AdvanceZCharacter('Freiza',1100,'Alien','Unknown',['Death comet','Death Ball'])
print(Freiza)
print(Freiza.getMoves())
print('*****************')
NewCharacter = Goku + Freiza
print(NewCharacter)
print(NewCharacter.getMoves())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-365daec708f3> in <module>
#      42
#      43 #Driver Code
# ---> 44 Tien = AdvanceZCharacter.createCharacter('Tien',['Tri beam'])
#      45 print(Tien)
#      46 print(Tien.getMoves())
#
# TypeError: createCharacter() missing 1 required positional argument: 'finisher'
