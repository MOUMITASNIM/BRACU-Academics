# %%
class Potion:
    def __init__(self, s_name,soup_no,s_ingredients):
        self.s_name = s_name
        self.soup_no=soup_no
        self.s_ingredients=s_ingredients



    def addSoup(self, soup):
      self.soups={}


    def addnutrients(self, nutrient):
      self.nutrients={}


      def showSoupByNo(self, soup_no):
        if soup_no in self.soups:
            s_name, s_ingredients = self.soups[soup_no]
            return f"Soup No: {soup_no}\nName: {s_name}\nIngredients: {s_ingredients}"
        return "Soup not found."

    def showNutrientsByNo(self, soup_no):
        if soup_no in self.s_nutrients:
            s_name, s_ratio = self.s_nutrients[soup_no]
            return f"Nutrient No: {soup_no}\nName: {s_name}\nRatio: {s_ratio}"
        return "Nutrient not found."

    def allSoups(self):
        print("All Soups:")
        print(f"Number of Soups: {len(self.soups)}")
        for soup_no, (s_name, s_ingredients) in self.soups.items():
            print(f"Soup No:[{soup_no}\nName: {s_name}\nIngredients: {s_ingredients}]")
            print(".......................")

    def allNutrients(self):
        print("All Nutrients:")
        print(f"Number of Nutrients: {len(self.nutrients)}")
        for no, (name, ratio) in self.nutrients.items():
            print(f"Nutrient No: {no}\nName: {name}\nRatio: {ratio}")
            print(".......................")


class Tonic1:
    def __init__(self, soup_no, s_category, soup_name, s_ingredients):
        self.no = soup_no
        self.category = s_category
        self.name = soup_name
        self.s_ingredients = s_ingredients


class Tonic2:
    def __init__(self, soup_no, s_category, soup_name, s_ratio):
        self.no = soup_no
        self.category = s_category
        self.name = soup_name
        self.ratio = s_ratio


# Driver Code
mix = Potion("Energy Broth")
s = Tonic1("s22", "soup", "Clear Soup", "ginger")
mix.addSoup(s)
print(".......................")
print(mix.showSoupByNo("s22"))
print(".......................")
n1 = Tonic2("n10", "nutrients", "Iron", 35)
mix.addnutrients(n1)
print(".......................")
print(mix.showNutrientsByNo("n10"))
print(".......................")
n2 = Tonic2("n45", "nutrients", "Zinc", 24)
mix.addnutrients(n2)
print(".......................")
print(mix.showNutrientsByNo("n45"))
print(".......................")
mix.allSoups()
mix.allNutrients()
# Out:
# .......................
# Soup No: s22
# Name: Clear Soup
# Ingredients: ginger
# .......................
# .......................
# Nutrient No: n10
# Name: Iron
# Ratio: 35mg
# .......................
# .......................
# Nutrient No: n45
# Name: Zinc
# Ratio: 24mg
# .......................
# All Soups:
# Number of Soups: 1
# Soup No:[s22
# Name: Clear Soup
# Ingredients: ginger]
# .......................
# All Nutrients:
# Number of Nutrients: 2
# Nutrient No: n10
# Name: Iron
# Ratio: 35mg
# .......................
# Nutrient No: n45
# Name: Zinc
# Ratio: 24mg
# .......................
