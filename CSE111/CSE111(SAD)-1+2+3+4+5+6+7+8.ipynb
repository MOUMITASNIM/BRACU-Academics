# %%
#Task_3

word=input("Enter a word:")
start_letter=False
start=0
end=0
index=0
for letter in word:
  if ord("A")<=ord(letter)<=ord("Z"):
   if start_letter==False:
     start=index
     start_letter=True
   else:
    end=index

  index+=1
word_2=word[start+1:end]
if len(word_2)>0:
  print(word_2)
else:
  print("BLANK")
# Out:
# Enter a word:coDIng
# BLANK

# %%
#task_4

string_1=input().split(",")
new_string=""

for i in string_1[0]:
  if i in string_1[1]:
    new_string+=i

for i in string_1[1]:
  if i in string_1[0]:
    new_string+=i

print(new_string)
# Out:
# harry, hermione
# hrrhr

# %%
#task_5
string = input("")
upper = False
lower = False
digit = False
symbol = False
new = ""
for i in string:
    if i >= "A" and i <= "Z":
        upper = True
    elif i >= "a" and i <= "z":
        lower = True
    elif i >= "0" and i <= "9":
        digit = True
    elif i >= "!" and i <= "@":
        symbol = True
if upper == False:
    print("Uppercase character missing" + ",")
if lower == False:
    print("Lowercase character missing" + ",")
if digit == False:
    print("Digit missing" + ",")
if symbol == False:
    print("Special character missing" + ",")
if new == "":
    print("OK")
# Out:
# OhMyBR@CU20
# OK

# %%
#LIST

#task_1
list_1 = []
dict_1 = {}
count_num = 0
while True:
    number = input("")
    if (number == "STOP"):
        break
    key_1 = int(number)
    if key_1 not in dict_1:
        count = 1
        dict_1[key_1] = count
    else:
        dict_1[key_1] = dict_1[key_1] + 1
for key_1,value_1 in dict_1.items():
    print(key_1,"-",value_1,"times")
# Out:
# 10
# 20
# 20
# 30
# 50
# 90
# STOP
# 10 - 1 times
# 20 - 2 times
# 30 - 1 times
# 50 - 1 times
# 90 - 1 times

# %%
#task_2
list_1 = []
list_2 = []
list_3 = []
sum_list = []
sum_1 = 0
sum_2 = 0
maxm = 0
num = int(input(""))
for i in range(num):
    num_1 = input("")
    num_2 = num_1.split(" ")
    for j in num_2:
        sum_1 += int(j)
        list_2.append(int(j))
    sum_list.append(sum_1)
    sum_1 = 0
    for k in range(len(sum_list)):
        if k == 0:
            maxm = sum_list[k]
        else:
            if sum_list[k] > maxm:
                maxm = sum_list[k]
    list_3.append(list_2)
    list_2 = []
print(maxm)
for a in list_3:
    for b in a:
        sum_2 += b
    if sum_2 == maxm:
        print(a)
    sum_2 = 0

# %%
#LIST

#task_5
n,k = input().split()
x = input().split()
counter=0
for i in x :
  if(5-int(i)>=int(k)):
    counter+=1
print(counter//3)
# Out:
# 5 2
# 0 4 5 1 0
# 1

# %% [markdown]
# LAB_2----CLASSWORK

# %%
#task_1
def BMI(height, weight):

    bmi_cal = weight/(0.01*height)**2
    result = bmi_cal

    if bmi_cal<18.5:
        print('Score is',result,'.You are','Underweight')
    elif 24.9>=bmi_cal>=18.5:
        print('Score is',result,'.You are','Normal')
    elif  30>=bmi_cal>=25:
        print('Overweight')
    elif bmi_cal>30:
       print('Score is',result,'.You are','Obese')


BMI(175, 96)
BMI(152, 48)
# Out:
# Score is 31.346938775510203 .You are Obese
# Score is 20.775623268698062 .You are Normal

# %%
#task_2
def order_food(item,location='Mohakhali'):
  menu_f={"BBQ Chicken Cheese Burger":250,"Beef Burger":170,"Naga Drums":200}
  meal_cost=menu_f[item]
  if location == 'Mohakhali':
     delivery_charge = 40
  else:
     delivery_charge = 60
  Total_Price = meal_cost + delivery_charge + (0.08*meal_cost)
  print(Total_Price)


order_food('Beef Burger', 'Dhanmondi')
order_food('Beef Burger')
# Out:
# 243.6
# 223.6

# %%
#Task_3
def replace_domain(email,n_dom,o_dom='kaaj.com'):

    prev_email = email.split('@')
    if prev_email[1] == o_dom:
        outcome = prev_email[0] + '@' + n_dom
        print ("Changed:",outcome)
    else:
        print ("Unchanged:",email)


replace_domain ('alice@kaaj.com','sheba.xyz','kaaj.com')
replace_domain ('bob@sheba.xyz','sheba.xyz')
# Out:
# Changed: alice@sheba.xyz
# Unchanged: bob@sheba.xyz

# %%
#task_4
def check_palindrome(word):
  new_word = ''
  old_word = ''

  for i in range(len(word)):
    if word[i] == ' ':
      continue
    else:
      old_word += word[i]

  for i in range(-1,-(len(old_word)+1),-1):
    new_word += old_word[i]

  if (old_word == new_word):
    print("Palindrome")
  else:
    print("Not a palindrome")

pali_input = input()
check_palindrome(pali_input)
# Out:
# hello
# Not a palindrome

# %%
#task_5
def ConvertD(number):
    years = number // 365
    months = (number % 365) // 30
    days = (number % 365) % 30
    print(f'Output:\n{years} years, {months} months and {days} days')
    return
ConvertD(int(input("Enter number of days: ")))
# Out:
# Enter number of days: 4320
# Output:
# 11 years, 10 months and 5 days

# %%
#task_6
def upper(sentence):
  symbol= '.?!'
  new_sen = ''
  space_n = 0
  punc_n = 0

  for i in range(len(sentence)):
    if (i == 0):
      new_sen += sentence[i].upper()
      continue
    else:
      if (sentence[i] in symbol):
        punc_n +=1
        new_sen+= sentence[i]
      elif (sentence[i] == " "):
        space_n +=1
        if (space_n > 1):
          space_n = 0
        new_sen+= sentence[i]

      elif (punc_n == 1 and space_n == 1):
        new_sen+= sentence[i].upper()
        punc_n = 0
        space_n = 0
      elif (space_n == 1 and sentence[i] == "i"):
          if (sentence[i+1] == ' '):
            new_sen+= sentence[i].upper()
          else:
            new_sen+= sentence[i]
          space_n = 0
          punc_n = 0
      else:
        new_sen+= sentence[i]
        space_n = 0
        punc_n = 0

  return new_sen

us_input = input()
print(upper(us_input))

# %% [markdown]
# HOMEWORK---LAB--1

# %%
from IPython.display import clear_output
import time

board = [[1,2,3],[4,5,6],[7,8,9]]
current_player_char = 'X'
next_player_char = 'O'
totalInputs = 9
winner = None


def checkHorizontal():
  for row in board:
    if row[0] == row[1] == row[2]:
      return True
  return False

def checkVertical():
  for col in range(3):
    if board[0][col] == board[1][col] == board[2][col]:
      return True
  return False

def checkDiagonal():
  if board[0][0] == board[1][1] == board[2][2] or board[0][2] == board[1][1] == board[2][0]:
    return True
  return False


def checkBoard():
  if checkHorizontal() or checkVertical() or checkDiagonal():
    return True
  return False

def placeCharacterOnBoard(pos):
  row = (pos - 1) // 3
  col = (pos - 1) % 3
  if board[row][col] == 'X' or board[row][col] == 'O':
    return 0
  board[row][col] = current_player_char
  return 1

def printCurrentBoard():
  print("-------------")
  for eachRow in board:
    print("|",end="")
    for eachCol in eachRow:
      print(f" {eachCol} ",end="|")
    print()
    print("-------------")

def runGame():
  global current_player_char
  global next_player_char
  global winner
  welcome_msg = '''Welcome to the TIC-TAC-TOE game. The first player to place character on the board will be Player 1(Character X) and the other player will be Player 2(Character O).'''
  print(welcome_msg)
  inputCount= 0
  while inputCount < totalInputs:
    printCurrentBoard()
    position = int(input(f"Player {(inputCount%2)+1}, enter a position that does not contain any X or O:"))
    validityofInput = placeCharacterOnBoard(position)
    inputCount += validityofInput
    if inputCount >= 5:
      if checkBoard():
        winner = "Player 1" if current_player_char == 'X' else "Player 2"
        clear_output()
        break
    if validityofInput:
      current_player_char, next_player_char = next_player_char, current_player_char
    clear_output()
  printCurrentBoard()
  if winner != None:
    print(f"Well done, {winner}. You have won the game.")
  else:
    print(f"The game ended in a draw")

runGame()
# Out:
# -------------
# | 1 | X | X |
# -------------
# | O | X | O |
# -------------
# | X | O | 9 |
# -------------
# Well done, Player 1. You have won the game.

# %% [markdown]
# LAB_3

# %% [markdown]
# Classwork

# %%
#TASK_1-CLASSWORK
class BankAccount :
  def __init__(self,name,type):
    self.user_name=name
    self.balance=1.0
    self.account_type=type


account1 = BankAccount("Bilbo", "Savings")
print("=====================================")
print(f"User Name: {account1.user_name}")
print(f"Balance: {account1.balance}")
print(f"Account Type:", account1.account_type)
print("=====================================")
account2 = BankAccount("Frodo", "Business")
print(f"User Name: {account2.user_name}")
print(f"Balance: {account2.balance}")
print(f"Account Type: {account2.account_type}")
print("=====================================")

account1.balance = 15.75
account2.balance = 700.50

print(f'New account balance of {account1.user_name} is {account1.balance} ')
print(f'New account balance of {account2.user_name} is {account2.balance} ')
# Out:
# ...
# User Name: Bilbo
# Balance: 1.0
# Account Type: Savings
# ...
# User Name: Frodo
# Balance: 1.0
# Account Type: Business
# ...
# New account balance of Bilbo is 15.75
# New account balance of Frodo is 700.5

# %%
#TASK_2-CLASSWORK

class MangoTree:
    def __init__(self, mango):
        self.variety = mango
        self.height = 1.0
        self.number_of_mangoes = 0

mangoTree1 = MangoTree("Gopalbhog")

print("=====================================")
print("Mango Tree Details:")
print(f"Variety: {mangoTree1.variety}")
print(f"Height: {mangoTree1.height} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree1.number_of_mangoes}")
print("=====================================")

mangoTree2 = MangoTree("Amrapali")

print("Mango Tree Details:")
print(f"Variety: {mangoTree2.variety}")
print(f"Height: {mangoTree2.height} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree2.number_of_mangoes}")
print("=====================================")

mangoTree1.height += 3 * 5
if mangoTree1.variety == 'Amrapali':
    mangoTree1.number_of_mangoes = mangoTree1.height * 15
elif mangoTree1.variety == 'Gopalbhog':
    mangoTree1.number_of_mangoes = mangoTree1.height * 10


print("Updated Mango Tree Details:")
print(f"Variety: {mangoTree1.variety}")
print(f"Height: {mangoTree1.height} meter(s)")
print(f"Number of mangoes on the tree: {mangoTree1.number_of_mangoes}")
print("=====================================")
# Out:
# ...
# Mango Tree Details:
# Variety: Gopalbhog
# Height: 1.0 meter(s)
# Number of mangoes on the tree: 0
# ...
# Mango Tree Details:
# Variety: Amrapali
# Height: 1.0 meter(s)
# Number of mangoes on the tree: 0
# ...
# Updated Mango Tree Details:
# Variety: Gopalbhog
# Height: 16.0 meter(s)
# Number of mangoes on the tree: 160.0
# ...

# %%
#TASK_3-CLASSWORK

class Contacts:
  def __init__(self,names,numbers):
    self.names=names
    self.numbers=numbers
    self.contactDict={}
    for i in range(len(names)):
            self.contactDict[names[i]] = numbers[i]
    if len(self.names)!=len(self.numbers):
     print('Contacts cannot be saved. Length Mismatch!')

    else:
      print('Contacts saved successfully')

m1 = Contacts(names, numbers)

names = ["Emergency", "Father", "Bestie"]
numbers = ["999", "01xx23", "01xx87", "01xx65", "01xx43"]

m1 = Contacts(names, numbers)
print("Saved Contacts:", m1.contactDict)
print("---------------------------------------------")

names.append("Mother")
numbers.pop()

m2 = Contacts(names, numbers)
print("Saved Contacts:", m2.contactDict)


#Subtasks:
#1:

#This line's execution creates a new instance of the "Contacts" class and calls the constructor.
#The criteria for length mismatch will be triggered since the "names" list includes one extra element ("Mother") but the "numbers" list has
#one less element (as a result of the pop operation). As a result, the message "Contacts cannot be saved. Length Mismatch!" will be shown.
#The "contactDict" attribute of the "m1" object will be generated with an empty dictionary.

#2

# Check if m1 and m2 are the same object
new_m1 = m1
print("Is m1 the same as m2?", m1 is m2)
print("Is new_m1 the same as m1?", new_m1 is m1)

#Although "m1" and "m2" are separate objects, "new_m1"—which was given the value of "m1"—is identical to "m1."
#This shows that the two "Contacts" objects "m1" and "m2" are separate instances and that creating a new object
#with the same variable name ("m1") would not change the one that was already made.
# Out:
# Contacts saved successfully
# Contacts cannot be saved. Length Mismatch!
# Saved Contacts: {'Emergency': '999', 'Father': '01xx23', 'Bestie': '01xx87'}
# ---------------------------------------------
# Contacts saved successfully
# Saved Contacts: {'Emergency': '999', 'Father': '01xx23', 'Bestie': '01xx87', 'Mother': '01xx65'}
# Is m1 the same as m2? False
# Is new_m1 the same as m1? True

# %%
#TASK-4-CLASSWORK

class Student:
    def __init__(self, name, cgpa, courses_taken):
        self.name = name
        self.cgpa = cgpa
        self.courses_taken = courses_taken
        self.student_status = self.calculate_student_status()
        self.advising_status = self.calculate_advising_status()
    print("All the best, Clark, for the upcoming semester.")

    def calculate_student_status(self):
        if self.cgpa < 2.00:
            return "Probation"
        else:
            return "Regular"

    def calculate_advising_status(self):
        if self.student_status == "Probation":
            if self.courses_taken >= 1 and self.courses_taken <= 2:
                return "Approved"
            else:
                return "Denied"
        elif self.student_status == "Regular":
            if self.courses_taken >= 3 and self.courses_taken <= 5:
                return "Approved"
            else:
                return "Denied"

    def display_advising_message(self):
        if self.advising_status == "Approved":
            if self.student_status == "Probation":
                print(f"Study hard this time, {self.name}.")
            elif self.student_status == "Regular":
                print(f"All the best, {self.name}, for the upcoming semester.")
        elif self.advising_status == "Denied":
            if self.student_status == "Probation":
                print(f"Sorry, {self.name}, you are on probation and cannot take more than 2 courses.")
            elif self.student_status == "Regular":
                print(f"Hello {self.name}, You are a regular student and have to take between 3 to 5 courses.")

# Driver code
s1 = Student("Clark", 3.45, 4)
print(f"Name: {s1.name}\nCGPA: {s1.cgpa}\nCourses Taken: {s1.courses_taken}")
print(f"Student Status: {s1.student_status}\nAdvising Status: {s1.advising_status}")
s1.display_advising_message()
print("--------------------------------------------------------------------------------")
s2 = Student("Barry", 1.93, 2)
print(f"Name: {s2.name}")
print(f"Student Status: {s2.student_status}\nAdvising Status: {s2.advising_status}")
s2.display_advising_message()
print("--------------------------------------------------------------------------------")
s3 = Student("Diana", 2.91, 2)
print(f"Advising Status: {s3.advising_status}\nCourses Taken: {s3.courses_taken}")
s3.display_advising_message()
print("--------------------------------------------------------------------------------")
s4 = Student("Bruce", 1.52, 5)
print(f"Advising Status: {s4.advising_status}\nCourses Taken: {s4.courses_taken}")
s4.display_advising_message()
# Out:
# All the best, Clark, for the upcoming semester.
# Name: Clark
# CGPA: 3.45
# Courses Taken: 4
# Student Status: Regular
# Advising Status: Approved
# All the best, Clark, for the upcoming semester.
# --------------------------------------------------------------------------------
# Name: Barry
# Student Status: Probation
# Advising Status: Approved
# Study hard this time, Barry.
# --------------------------------------------------------------------------------
# Advising Status: Denied
# Courses Taken: 2
# Hello Diana, You are a regular student and have to take between 3 to 5 courses.
# --------------------------------------------------------------------------------
# Advising Status: Denied
# Courses Taken: 5
# Sorry, Bruce, you are on probation and cannot take more than 2 courses.

# %%
#TASK_5_CLASSWORK

import datetime

class Book:
    def __init__(self, name, author, year_of_publication):
        self.name = name
        self.author = author
        self.year_of_publication = year_of_publication
        self.status = self.check_antique_status()

    def check_antique_status(self):
        today = datetime.date.today()
        current_year = today.year
        age = current_year - self.year_of_publication

        if age >= 400:
            return "Accepted. The book is stored on floor: 2"
        elif age >= 200:
            return "Accepted. The book is stored on floor: 1"
        else:
            return "Rejected. The book is not antique enough."

# Driver code
book1= Book('The Act', 'Ferguson', 1924)
print("Checking the book.")
print(f"{book1.author} wrote the book '{book1.name}'.")
print(f"This book was published in {book1.year_of_publication}.")
print(f"This book is {book1.status}")
print("-------------------------------------")
book2= Book('Flame', 'Nolan', 1932)
print("Checking the book.")
print(f"{book2.author} wrote the book '{book2.name}'.")
print(f"This book was published in {book2.year_of_publication}.")
print(f"This book is {book2.status}")
print("-------------------------------------")
book3= Book('Norms', 'Alfred', 1832)
print("Checking the book.")
print(f"{book3.author} wrote the book '{book3.name}'.")
print(f"This book was published in {book3.year_of_publication}.")
print(f"This book is {book3.status}")
print("-------------------------------------")
book4= Book('Apex', 'Samson', 1923)
print("Checking the book.")
print(f"{book4.author} wrote the book '{book4.name}'.")
print(f"This book was published in {book4.year_of_publication}.")
print(f"This book is {book4.status}")
print("-------------------------------------")
book5= Book('Habitat', 'Eden', 1723)
print("Checking the book.")
print(f"{book5.author} wrote the book '{book5.name}'.")
print(f"This book was published in {book5.year_of_publication}.")
print(f"This book is {book5.status}")
print("-------------------------------------")
book6= Book('Apocalypto', 'Menez', 1603)
print("Checking the book.")
print(f"{book6.author} wrote the book '{book6.name}'.")
print(f"This book was published in {book6.year_of_publication}.")
print(f"This book is {book6.status}")
# Out:
# Checking the book.
# Ferguson wrote the book 'The Act'.
# This book was published in 1924.
# This book is Rejected. The book is not antique enough.
# -------------------------------------
# Checking the book.
# Nolan wrote the book 'Flame'.
# This book was published in 1932.
# This book is Rejected. The book is not antique enough.
# -------------------------------------
# Checking the book.
# Alfred wrote the book 'Norms'.
# This book was published in 1832.
# This book is Rejected. The book is not antique enough.
# -------------------------------------
# Checking the book.
# Samson wrote the book 'Apex'.
# This book was published in 1923.
# This book is Rejected. The book is not antique enough.
# -------------------------------------
# Checking the book.
# Eden wrote the book 'Habitat'.
# This book was published in 1723.
# This book is Accepted. The book is stored on floor: 1
# -------------------------------------
# Checking the book.
# Menez wrote the book 'Apocalypto'.
# ...

# %% [markdown]
# LAB-3-HOMEWORK

# %%
#TASK-1-HOMEWORK

class CellPackage:
    def __init__(self, data, talk_time, messages, cashback, validity, price):
        self.data = int(data) * 1024  # Convert GB to MB
        self.talk_time =talk_time
        self.messages = int(messages)
        self.cashback = int(cashback) if cashback != '0%' else 0
        self.validity = validity
        self.price = int(price)

    def display_package_info(self):
        print("Data =", self.data, "MB")
        print("Talktime =", self.talk_time, "Minutes")
        if self.messages != 0:
            print("SMS/MMS =", self.messages)
        print("Validity =", self.validity, "Days")
        print("--> Price =", self.price, "tk")
        if self.cashback != 0:
            print("Buy now to get", self.cashback, "tk cashback.")
        print()

pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
print('============= Package 1 =============')
pkg.display_package_info()

pkg2 = CellPackage(700, '35 GB', 700, 0, '10%', 30)
print('============= Package 2 =============')
pkg2.display_package_info()

pkg3 = CellPackage(120, '0 GB', 190, 0, '0%', 10)
print('============= Package 3 =============')
pkg3.display_package_info()
# Out:
# ============= Package 1 =============
# Data = 153600 MB
# Talktime = 6 GB Minutes
# SMS/MMS = 99
# Validity = 7% Days
# --> Price = 7 tk
# Buy now to get 20 tk cashback.
#
# ============= Package 2 =============
# Data = 716800 MB
# Talktime = 35 GB Minutes
# SMS/MMS = 700
# Validity = 10% Days
# --> Price = 30 tk
#
# ============= Package 3 =============
# Data = 122880 MB
# Talktime = 0 GB Minutes
# SMS/MMS = 190
# Validity = 0% Days
# --> Price = 10 tk

# %%
#TASK-2-HOMEWORK
class Pokemon:
  def __init__(self,pokemon1_name,pokemon2_name,pokemon1_power,pokemon2_power,damage_rate):
    self.pokemon1_name=pokemon1_name
    self.pokemon2_name=pokemon2_name
    self.pokemon1_power=pokemon1_power
    self.pokemon2_power=pokemon2_power
    self.damage_rate=damage_rate



team_pika = Pokemon('pikachu', 'charmander', 90, 60, 10)
print('=======Team 1=======')
print('Pokemon 1:',team_pika.pokemon1_name,team_pika.pokemon1_power)
print('Pokemon 2:',team_pika.pokemon2_name,team_pika.pokemon2_power)
pika_combined_power = (team_pika.pokemon1_power +
team_pika.pokemon2_power) * team_pika.damage_rate
print('Combined Power:', pika_combined_power)


#Subtask:
#2
team_bulb = Pokemon('bulbasaur', 'squirtle', 80, 70, 9)
#3
print('=======Team 2=======')
print('Pokemon 1:',team_bulb.pokemon1_name, team_bulb.pokemon1_power)
print('Pokemon 2:',team_bulb.pokemon2_name, team_bulb.pokemon2_power)
bulb_combined_power = (team_bulb.pokemon1_power + team_bulb.pokemon2_power) * team_bulb.damage_rate
print('Combined Power:', bulb_combined_power)
# Out:
# =======Team 1=======
# Pokemon 1: pikachu 90
# Pokemon 2: charmander 60
# Combined Power: 1500
# =======Team 2=======
# Pokemon 1: bulbasaur 80
# Pokemon 2: squirtle 70
# Combined Power: 1350

# %%
#TASK-3-HOMEWORK

#Part-A
class box:
  def __init__(self,value):
    self.height=value[0]
    self.width=value[1]
    self.breadth=value[2]
    print("Creating a Box!")
    print("volume of the box is",{self.height*self.width*self.breadth}, "cubic units")


print("Box 1")
b1 = box([10,10,10])
print("=========================")
print("Height:", b1.height)
print("Width:", b1.width)
print("Breadth:", b1.breadth)
volume = b1.height * b1.width * b1.breadth
print(f"Volume of the box is {volume} cubic units.")
print("-------------------------")
print("Box 2")
b2 = box((30,10,10))
print("=========================")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
volume = b2.height * b2.width * b2.breadth
print(f"Volume of the box is {volume} cubic units.")
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
volume = b2.height * b2.width * b2.breadth
print(f"Volume of the box is {volume} cubic units.")
print("-------------------------")
print("Box 3")
b3 = b2
print("Height:", b3.height)
print("Width:", b3.width)
print("Breadth:", b3.breadth)
volume = b3.height * b3.width * b3.breadth
print(f"Volume of the box is {volume} cubic units.")

#PART-B
one = (b3 == b2)

b3.width = 100
two = (b3 == b2)
print("Value of 'one':", one)
print("Value of 'two':", two)
print("Value of 'b2.width':", b2.width)

#The value of one: Since b3 and b2 both refer to the same object (b2 = b3), the comparison b3 == b2 will evaluate to True. So, one will be True.
#The value of two: After updating b3.width to 100, the value of b2.width will also change because both b2 and b3 are references to the same object.
#So, two will be True as well.
#The value of b2.width: The value of b2.width will be 100 since b2 and b3 refer to the same object, and updating b3.width also changes b2.width.
# Out:
# Box 1
# Creating a Box!
# volume of the box is {1000} cubic units
# ...
# Height: 10
# Width: 10
# Breadth: 10
# Volume of the box is 1000 cubic units.
# -------------------------
# Box 2
# Creating a Box!
# volume of the box is {3000} cubic units
# ...
# Height: 30
# Width: 10
# Breadth: 10
# Volume of the box is 3000 cubic units.
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# Value of 'one': True
# Value of 'two': True
# Value of 'b2.width': 100

# %%
#TASK-4-HOMEWORK

class Vector3D:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
        print(f'Vector <{self.x}, {self.y}, {self.z}> has been created.')

    def magnitude(self):
        return (self.x**2 + self.y**2 + self.z**2)**0.5

    def dot_product(self, other):
        return self.x * other.x + self.y * other.y + self.z * other.z

    def cross_product(self, other):
        cross_x = self.y * other.z - self.z * other.y
        cross_y = self.z * other.x - self.x * other.z
        cross_z = self.x * other.y - self.y * other.x
        return Vector3D(cross_x, cross_y, cross_z)

V1 = Vector3D(2, -3, 1)
V2 = Vector3D(-1, 4, 0)

print(f"Magnitude of the first vector = {V1.magnitude()}")
print(f"Magnitude of the second vector = {V2.magnitude()}")
print(f"Dot product of the two vectors = {V1.dot_product(V2)}")

cross_product = V1.cross_product(V2)
print(f"Cross product of the two vectors = <{cross_product.x}, {cross_product.y}, {cross_product.z}>")
# Out:
# Vector <2, -3, 1> has been created.
# Vector <-1, 4, 0> has been created.
# Magnitude of the first vector = 3.7416573867739413
# Magnitude of the second vector = 4.123105625617661
# Dot product of the two vectors = -14
# Vector <-4, -1, 5> has been created.
# Cross product of the two vectors = <-4, -1, 5>

# %%
#TASK-5-HOMEWORK

class Order:
    def __init__(self, menu, order_string):
        self.items = []
        self.menu = menu
        self.parse_order_string(order_string)

    def parse_order_string(self, order_string):
        order_list = order_string.split(", ")
        for order in order_list:
            item, quantity = order.split("-")
            item = item.strip()
            quantity = int(quantity)
            price = self.menu[item] * quantity
            self.items.append(item)
            self.items.append(quantity)
            self.items.append(price)


menu = {
    'Chicken_Cheeseburger' : 249,
    'Mega_Cheeseburger' : 289,
    'Fries' : 139,
    'Hot_Wings' : 99,
    'Rice_Bowl' : 299,
    'Soft_Drinks' : 50
}

order1 = Order(menu, "Chicken_Cheeseburger-2, Fries-3, Soft_Drinks-3")
print(order1.items)
print()

print('-'*35)
print('Item           x Quantity :   Price')
print('--------------   --------   -------')

index = 0
total = 0
while index < len(order1.items):
  item = order1.items[index]
  quantity = order1.items[index+1]
  price = order1.items[index+2]

  print(f'{item:20} x {quantity:2} : {price:7.2f}')
  total += price
  index += 3 # Going to next item

print('-'*35)
print(f'Total:                      {total:7.2f}')
print('-'*35)
# Out:
# ['Chicken_Cheeseburger', 2, 498, 'Fries', 3, 417, 'Soft_Drinks', 3, 150]
#
# -----------------------------------
# Item           x Quantity :   Price
# --------------   --------   -------
# Chicken_Cheeseburger x  2 :  498.00
# Fries                x  3 :  417.00
# Soft_Drinks          x  3 :  150.00
# -----------------------------------
# Total:                      1065.00
# -----------------------------------

# %% [markdown]
# LAB-4-CLASSWORK

# %%
#TASK-1-CLASSWORK

class Customer:

  def __init__(self):
    self.tickets=[]
    self.tot_price=0
    print("Welcome to ABC Memorial Park")

  def buyTicket(self,c_name,c_age):
    if len(self.tickets)>=3 :
      print("You can't buy more than 3 tickets")
    else :

      if c_age>10 :
        tick_price = 100
      else:
        tick_price = 50

      self.tickets.append({'name': c_name,'price':tick_price})
      self.tot_price += tick_price
      print(f'Successfully purchased a ticket for {c_name}!')

  def showDetails(self):
    print(f'Amount of tickets:{len(self.tickets)}')
    print(f'Total price: {self.tot_price} Taka')


#driver code
print('1-------------------------')
customer1 = Customer()
print('2-------------------------')
customer1.buyTicket('Bob', 23)
customer1.buyTicket('Henry', 7)
customer1.buyTicket('Alexa', 30)
customer1.buyTicket('Jonas', 43)
print('3-------------------------')
customer1.showDetails()
print('4-------------------------')
customer2 = Customer()
print('5-------------------------')
customer2.buyTicket('Harry', 60)
customer2.buyTicket('Tomas', 28)
print('6-------------------------')
customer2.showDetails()
# Out:
# 1-------------------------
# Welcome to ABC Memorial Park
# 2-------------------------
# Successfully purchased a ticket for Bob!
# Successfully purchased a ticket for Henry!
# Successfully purchased a ticket for Alexa!
# You can't buy more than 3 tickets
# 3-------------------------
# Amount of tickets:3
# Total price: 250 Taka
# 4-------------------------
# Welcome to ABC Memorial Park
# 5-------------------------
# Successfully purchased a ticket for Harry!
# Successfully purchased a ticket for Tomas!
# 6-------------------------
# Amount of tickets:2
# Total price: 200 Taka

# %%
#TASK-2-CLASSWORK

class SentenceAnalyzer:

    def __init__(self, p_sentence = None):
        self.p_sentence = p_sentence

    def set_sentence(self, p_sentence):
        self.p_sentence = p_sentence

    def get_word_count(self, s_word_length = None):
        if not self.p_sentence:
            print("Sentence is not set.")
            return

        words = self.p_sentence.split()

        if s_word_length is None:
            print(f"Number of words in the sentence: {len(words)}")
        else:
            new_words = [word for word in words if len(words) == s_word_length]
            print(f"Number of words with {s_word_length} characters in the sentence: {len(new_words)}")


# Driver Code
analyzer1 = SentenceAnalyzer()
analyzer1.set_sentence("That's an easy one")
print("1--------------------------")
analyzer1.get_word_count()
print("2--------------------------")
analyzer2 = SentenceAnalyzer("Like I said it's easy")
print("3--------------------------")
analyzer2.get_word_count()
print("4--------------------------")
analyzer2.get_word_count(4)
print("5--------------------------")
analyzer1.get_word_count(5)
# Out:
# 1--------------------------
# Number of words in the sentence: 4
# 2--------------------------
# 3--------------------------
# Number of words in the sentence: 5
# 4--------------------------
# Number of words with 4 characters in the sentence: 4
# 5--------------------------
# Number of words with 5 characters in the sentence: 0

# %%
#TASK-3-CLASSWORK

class Student:
    def __init__(self, s_name, s_cgpa, n_of_credits=None, dept=None):

        self.s_name = s_name
        self.s_cgpa = s_cgpa
        self.n_of_credits = n_of_credits
        self.dept = dept
        self.scholars_status = None

    def checkScholarshipEligibility(self):

        if self.s_cgpa >= 3.7:
            self.scholars_status = "Merit-based scholarship"
        elif self.s_cgpa >= 3.5 and self.s_cgpa < 3.7:
            self.scholars_status = "Need-based scholarship"
        else:
            self.scholars_status = "No scholarship"

    def showDetails(self):

        print("Name:", self.s_name)
        if self.dept:
            print("Department:", self.dept)
        print("CGPA:", self.s_cgpa)
        if self.n_of_credits:
            print("Number of Credits:", self.n_of_credits)
        print("Scholarship Status:", self.scholars_status)


# Driver Code
print('--------------------------')
std1 = Student("Alif", 3.99, 12)
print('--------------------------')
std1.checkScholarshipEligibility()
print('--------------------------')
std1.showDetails()
print('--------------------------')
std2 = Student("Mim", 3.4)
std3 = Student("Henry", 3.5, 15, "BBA")
print('--------------------------')
std2.checkScholarshipEligibility()
print('--------------------------')
std3.checkScholarshipEligibility()
print('--------------------------')
std2.showDetails()
print('--------------------------')
std3.showDetails()
print('--------------------------')
std4 = Student("Bob", 4, 6, "CSE")
print('--------------------------')
std4.checkScholarshipEligibility()
print('--------------------------')
std4.showDetails()
# Out:
# --------------------------
# --------------------------
# --------------------------
# Name: Alif
# CGPA: 3.99
# Number of Credits: 12
# Scholarship Status: Merit-based scholarship
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# Name: Mim
# CGPA: 3.4
# Scholarship Status: No scholarship
# --------------------------
# Name: Henry
# Department: BBA
# CGPA: 3.5
# Number of Credits: 15
# Scholarship Status: Need-based scholarship
# --------------------------
# --------------------------
# --------------------------
# Name: Bob
# Department: CSE
# CGPA: 4
# Number of Credits: 6
# Scholarship Status: Merit-based scholarship

# %%
#TASK-4-CLASSWORK

class Author:
    def __init__(self, aut_name=None):
        self.aut_name = aut_name
        self.n_books = {}

    def setName(self, aut_name):
        self.aut_name = aut_name

    def addBook(self, books_name, genre):
        if self.aut_name is None:
            print("A book cannot be added without an author name")
        else:
            if genre not in self.n_books:
                self.n_books[genre] = []
            self.n_books[genre].append(books_name)

    def printDetail(self):
        if self.aut_name is None:
            print("Author name is not set.")
            return

        print("Number of Book(s):", len(self.n_books))
        print("Author Name:", self.aut_name)
        for genre, n_books in self.n_books.items():
            book_list = ""
            for book in n_books:
                if book_list:
                    book_list += ", "
                book_list += book
            print(f"{genre}: {book_list}")

# Driver Code
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book cannot be added without an author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# ...

# %%
#TASK-5-CLASSWORK

class TaxiLagbe:
    def __init__(self, taxi_num, t_location):
        self.taxi_num = taxi_num
        self.t_location = t_location
        self.t_passengers = []
        self.collect_fare = 0

    def addPassenger(self, *t_passengers):
        for passenger in t_passengers:
            name, fare = passenger.split('_')
            self.t_passengers.append(name)
            self.collect_fare += int(fare)
            if len(self.t_passengers) == 4:
                print('Taxi Full! No more passengers can be added.')

                break

    def printDetails(self):
        print(f'Trip info for Taxi number: {self.taxi_num}')
        print(f'This taxi can only cover the {self.t_location} area.')
        print(f'Total passengers: {len(self.t_passengers)}')
        print('Passenger lists:')
        for passenger in self.t_passengers:
            print(passenger, end=',')
        print(f'\nTotal collected fare: {self.collect_fare} Taka')


# Driver Code
taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200', 'Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115', 'Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker,Wood,Matt,Wilson,
# Total collected fare: 505 Taka
# -------------------------------
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 5
# Passenger lists:
# Walker,Wood,Matt,Wilson,Karen,
# Total collected fare: 705 Taka
# -------------------------------
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can only cover the Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald,Parker,
# Total collected fare: 330 Taka

# %% [markdown]
# LAB-4-HOMEWORK

# %%
#TASK-1-HOMEWORK

class HackathonTeam:
    def __init__(self, hteam_name, membr_1=None, membr_2=None, membr_3=None):
        self.hteam_name = hteam_name
        self.members = [membr_1, membr_2, membr_3]

    def information(self):
        print("Team name:", self.hteam_name)
        print("Participants:")
        for member in self.members:
            if member is not None:
                print(member)


#driver_code
team_1 = HackathonTeam("Atlantean", "Aquaman")
team_1.information()

print("=================")

team_2 = HackathonTeam("Avengers", "Ironman", "Thor", "Hulk")
team_2.information()

print("=================")

team_3 = HackathonTeam("X-Men", "Storm", "Mystique")
team_3.information()
# Out:
# Team name: Atlantean
# Participants:
# Aquaman
# ...
# Team name: Avengers
# Participants:
# Ironman
# Thor
# Hulk
# ...
# Team name: X-Men
# Participants:
# Storm
# Mystique

# %%
#TASK-2-HOMEWORK

class Foodie:
    menu = {'Chicken Lollipop': 15, 'Beef Nugget': 20, 'Americano': 180, 'Red Velvet': 150, 'Prawn Tempura': 80, 'Saute Veg': 200}

    def __init__(self, itm_name):
        self.itm_name = itm_name
        self.menu_cart = []
        self.total_moneyspent = 0

    def show_orders(self):
        numb_of_items = len(self.menu_cart)
        print(f"{self.itm_name} has {numb_of_items} item(s) in the cart.")
        print("Items:", self.menu_cart)
        print(f"Total spent: {self.total_moneyspent}.")
        print()

    def order(self, *f_items):
        for item in f_items:
            fitem_name, f_quantity = item.split('-')
            fitem_name = fitem_name.strip()
            f_quantity = int(f_quantity)
            if fitem_name in self.menu:
                prices_per_unit = self.menu[fitem_name]
                total_price = prices_per_unit * f_quantity
                self.menu_cart.append(fitem_name)
                self.total_moneyspent += total_price
                print(f"Ordered - {fitem_name}, quantity - {f_quantity}, price (per Unit) - {prices_per_unit}.")
                print(f"Total price - {total_price}")
        print()

    def pay_tips(self, w_tips=0):
        if w_tips > 0:
            print(f"Gives {w_tips}/- tips to the waiter.")
        else:
            print("No tips to the waiter.")
        print()


# Driver Code
f1 = Foodie('Frodo')
f1.show_orders()
print('1----------------------')
f1.order('Chicken Lollipop-3', 'Beef Nugget-6', 'Americano-1')
print('2----------------------')
f1.show_orders()
print('3----------------------')
f1.order('Red Velvet-1')
print('4----------------------')
f1.pay_tips(20)
print('5----------------------')
f1.show_orders()

f2 = Foodie('Bilbo')
print('6----------------------')
f2.order('Prawn Tempura-6', 'Saute Veg-1')
print('7----------------------')
f2.pay_tips()
print('8----------------------')
f2.show_orders()
# Out:
# Frodo has 0 item(s) in the cart.
# Items: []
# Total spent: 0.
#
# 1----------------------
# Ordered - Chicken Lollipop, quantity - 3, price (per Unit) - 15.
# Total price - 45
# Ordered - Beef Nugget, quantity - 6, price (per Unit) - 20.
# Total price - 120
# Ordered - Americano, quantity - 1, price (per Unit) - 180.
# Total price - 180
#
# 2----------------------
# Frodo has 3 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano']
# Total spent: 345.
#
# 3----------------------
# Ordered - Red Velvet, quantity - 1, price (per Unit) - 150.
# Total price - 150
#
# 4----------------------
# Gives 20/- tips to the waiter.
#
# 5----------------------
# Frodo has 4 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano', 'Red Velvet']
# Total spent: 495.
#
# 6----------------------
# Ordered - Prawn Tempura, quantity - 6, price (per Unit) - 80.
# Total price - 480
# Ordered - Saute Veg, quantity - 1, price (per Unit) - 200.
# ...

# %%
#TASK-3-HOMEWORK

class Farmer:
    def __init__(self, name=""):
        self.name = name
        self.crops = []
        self.fishes = []
        print("Welcome to your farm!")

    def addCrops(self, *crops):
        num_crops = len(crops)
        self.crops += list(crops)
        print(f"{num_crops} crop(s) added.")

    def addFishes(self, *fishes):
        num_fishes = len(fishes)
        self.fishes += list(fishes)
        print(f"{num_fishes} fish(s) added.")

    def showGoods(self):
        if self.name:
            print(f"Welcome to your farm, {self.name}!")
        else:
            print("Welcome to your farm!")

        num_crops = len(self.crops)
        num_fishes = len(self.fishes)
        print(f"You have {num_crops} crop(s):")
        if num_crops > 0:
            print(",".join(self.crops))
        else:
            print("You don't have any crop(s).")
        print(f"You have {num_fishes} fish(s):")
        if num_fishes > 0:
            print(",".join(self.fishes))
        else:
            print("You don't have any fish(s).")



# Driver Code
f1 = Farmer()
print("-------------------")
f1.addCrops('Rice', 'Jute', 'Cinnamon')
print("-------------------")
f1.addFishes()
print("-------------------")
f1.addCrops('Mustard')
print("-------------------")
f1.showGoods()
print("-------------------")

f2 = Farmer("Korim Mia")
print("-------------------")
f2.addFishes('Pangash', 'Magur')
print("-------------------")
f2.addCrops("Wheat", "Potato")
print("-------------------")
f2.addFishes("Koi", "Tuna", "Sardine")
print("-------------------")
f2.showGoods()
print("-------------------")

f3 = Farmer(2865127000)
print("-------------------")
f3.addCrops()
print("-------------------")
f3.addFishes("Katla")
print("-------------------")
f3.showGoods()
print("-------------------")
# Out:
# Welcome to your farm!
# -------------------
# 3 crop(s) added.
# -------------------
# 0 fish(s) added.
# -------------------
# 1 crop(s) added.
# -------------------
# Welcome to your farm!
# You have 4 crop(s):
# Rice,Jute,Cinnamon,Mustard
# You have 0 fish(s):
# You don't have any fish(s).
# -------------------
# Welcome to your farm!
# -------------------
# 2 fish(s) added.
# -------------------
# 2 crop(s) added.
# -------------------
# 3 fish(s) added.
# -------------------
# Welcome to your farm, Korim Mia!
# You have 2 crop(s):
# Wheat,Potato
# You have 5 fish(s):
# Pangash,Magur,Koi,Tuna,Sardine
# -------------------
# Welcome to your farm!
# -------------------
# 0 crop(s) added.
# -------------------
# 1 fish(s) added.
# -------------------
# Welcome to your farm, 2865127000!
# You have 0 crop(s):
# You don't have any crop(s).
# You have 1 fish(s):
# Katla
# -------------------

# %%
class UniversalStudiosUser:
    def __init__(self, name, age, category):
        self.name = name
        self.age = age
        self.category = category
        self.selected_rides_list = []
        self.total_amount = 0
        print("Welcome to Universal Studios.")

    def selected_rides(self, *rides):
        for ride in rides:
            ride_name, amount = ride.split('-')
            self.selected_rides_list.append((ride_name, int(amount)))
            self.total_amount += int(amount)
        print("Added ride(s) successfully.")
        print("-----------------")

    def show_details(self):
        print("Your information:")
        print(f"Name: {self.name}, Age: {self.age}, Category: {self.category}")
        print("Selected rides:")
        for ride_name, amount in self.selected_rides_list:
            print(f"Ride: {ride_name}, Amount: {amount} dollar(s)")
        if self.category == "Special" and len(self.selected_rides_list) > 3:
            discount = 0.2 * self.total_amount
            self.total_amount -= discount
            print("Congratulations!!! You've got a 20% discount.")
        print(f"Please pay {self.total_amount} dollar(s).")
        print("=================")


# Driver Code
customer_1 = UniversalStudiosUser("Alice", 21, "Special")
print("--------- 1 ---------")
customer_1.selected_rides("Waterworld-100", "Accelerator-200", "DinoSoarin-50")
print("--------- 2 ---------")
customer_1.show_details()

print("=================")

customer_2 = UniversalStudiosUser("Bob", 20, "Normal")
print("--------- 3 ---------")
customer_2.selected_rides("Enchanted Airways-300", "Jurassic Park-500", "Accelerator-200", "DinoSoarin-50")
print("--------- 4 ---------")
customer_2.show_details()

print("=================")

customer_3 = UniversalStudiosUser("Mark", 15, "Special")
print("--------- 5 ---------")
customer_3.selected_rides("Transformers-450", "Jurassic Park-500", "Waterworld-100", "DinoSoarin-50")
print("--------- 6 ---------")
customer_3.show_details()
# Out:
# Welcome to Universal Studios.
# --------- 1 ---------
# Added ride(s) successfully.
# -----------------
# --------- 2 ---------
# Your information:
# Name: Alice, Age: 21, Category: Special
# Selected rides:
# Ride: Waterworld, Amount: 100 dollar(s)
# Ride: Accelerator, Amount: 200 dollar(s)
# Ride: DinoSoarin, Amount: 50 dollar(s)
# Please pay 350 dollar(s).
# ...
# Welcome to Universal Studios.
# --------- 3 ---------
# Added ride(s) successfully.
# -----------------
# --------- 4 ---------
# Your information:
# Name: Bob, Age: 20, Category: Normal
# Selected rides:
# Ride: Enchanted Airways, Amount: 300 dollar(s)
# Ride: Jurassic Park, Amount: 500 dollar(s)
# Ride: Accelerator, Amount: 200 dollar(s)
# Ride: DinoSoarin, Amount: 50 dollar(s)
# Please pay 1050 dollar(s).
# ...
# Welcome to Universal Studios.
# --------- 5 ---------
# Added ride(s) successfully.
# -----------------
# --------- 6 ---------
# Your information:
# Name: Mark, Age: 15, Category: Special
# Selected rides:
# ...

# %%
class Department:
  def __init__(self,department='ChE Department',section=5):
    self.department = department
    self.section = section
    print(f'The {self.department} has {self.section} sections')
    self.average = 0
    self.add = 0
  def add_students(self,*add):
    if self.section == len(add):
      for j in add:
        self.add += j
      self.average = self.add/self.section
      print(f'The {self.department} has an average of {self.average} students in each section')
    else:
      print(f"The {self.department}  doesn't have {len(add)} sections")

  def merge_Department(self,*dep):
    for i in dep:
      print(f'{i.department} is merged to {self.department} Department.')
      self.add += i.add
    return f'Now the {self.department} has an average of {self.add/self.section} students in each section.'




d1 = Department()
print('1-----------------------------------')
d2 = Department('MME Department')
print('2-----------------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------------')
mega.add_students(21,30,40,36,10,32,27,51,45,15)
print('8-----------------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------------')
print(mega.merge_Department(d3))
# Out:
# The ChE Department has 5 sections
# 1-----------------------------------
# The MME Department has 5 sections
# 2-----------------------------------
# The NCE Department has 8 sections
# 3-----------------------------------
# The ChE Department has an average of 20.4 students in each section
# 4-----------------------------------
# The MME Department  doesn't have 3 sections
# 5-----------------------------------
# The NCE Department has an average of 29.875 students in each section
# 6-----------------------------------
# The Engineering Department has 10 sections
# 7-----------------------------------
# The Engineering Department has an average of 30.7 students in each section
# 8-----------------------------------
# ChE Department is merged to Engineering Department Department.
# MME Department is merged to Engineering Department Department.
# Now the Engineering Department has an average of 40.9 students in each section.
# 9-----------------------------------
# ...

# %%
class StudentRoutineGenerator:
    def __init__(self, name, max_courses):
        self.name = name
        self.max_courses = max_courses
        self.routine = {'Sat/Thurs': {}, 'Sun/Tue': {}, 'Mon/Wed': {}}

    def addCourses(self, *courses):
        for course in courses:

            course_details = course.split('-')
            course_name = course_details[0]
            days_and_time = course_details[1]
            days, time = days_and_time.split('/')

            if days not in self.routine:

                self.routine[days] = {}

            if course_name in self.getCourseNames():
                print("You already have", course_name, "in your routine")
            elif self.getCourseCount() == self.max_courses:
                print("You can't take more than", self.max_courses, "courses")
            elif self.checkClash(days, time):
                print("Can't take", course_name + ". It's clashing with your", self.getClashingCourse(days, time))
            else:
                self.routine[days][time] = course_name
                print("Successfully added", course_name + "!")

    def dropCourse(self, course_name):
        if course_name in self.getCourseNames():
            for days in self.routine:
                if self.routine[days].get(course_name):
                    del self.routine[days][course_name]
            print("Successfully dropped", course_name)
        else:
            print("No such course in your routine")

    def showRoutine(self):
        print("##################################")
        print("Name:", self.name)
        print("Maximum Number of Courses:", self.max_courses)
        print("Initial Routine:", self.routine)
        print("------------------------------")
        print("Updated Routine:")
        print(self.routine)
        print("Routine Details:")
        for days in self.routine:
            if self.routine[days]:
                print(days + ":")
                for time, course in self.routine[days].items():
                    print(time + " -", course)
        print()

    def getCourseNames(self):
        course_names = []
        for days in self.routine:
            for course in self.routine[days].values():
                course_names.append(course)
        return course_names

    def getCourseCount(self):
        return len(self.getCourseNames())

    def checkClash(self, days, time):
        return self.routine[days].get(time)

    def getClashingCourse(self, days, time):
        return self.routine[days][time]



#driver_code
print('##################################')
st1 = StudentRoutineGenerator('Harry', 4)
print('------------------------------')
st1.addCourses('CSE110-Mon/Wed-12:30', 'MAT110-Mon/Wed-2:00')
st1.addCourses('ENG101-Sun/Tue-12:30', 'CSE110-Mon/Wed-9:30')
st1.addCourses('PHY111-Sun/Tue-12:30')
print('------------------------------')
st1.showRoutine()
print('------------------------------')
st1.dropCourse('CSE110')
st1.dropCourse('PHY112')
print('------------------------------')
st1.showRoutine()
print('##################################')
st2 = StudentRoutineGenerator('John', 3)
print('------------------------------')
st2.addCourses('MAT110-Mon/Wed-8:00')
st2.addCourses('ENG101-Sat/Thurs-12:30', 'CSE110-Sun/Tue-9:30')
st2.addCourses('PHY111-Sun/Tue-12:30')
print('------------------------------')
st2.showRoutine()
# Out:
# ##################################
# ------------------------------
# Successfully added CSE110!
# Can't take MAT110. It's clashing with your CSE110
# Successfully added ENG101!
# You already have CSE110 in your routine
# Can't take PHY111. It's clashing with your ENG101
# ------------------------------
# ##################################
# Name: Harry
# Maximum Number of Courses: 4
# Initial Routine: {'Sat/Thurs': {}, 'Sun/Tue': {}, 'Mon/Wed': {}, 'Mon': {'Wed': 'CSE110'}, 'Sun': {'Tue': 'ENG101'}}
# ------------------------------
# Updated Routine:
# {'Sat/Thurs': {}, 'Sun/Tue': {}, 'Mon/Wed': {}, 'Mon': {'Wed': 'CSE110'}, 'Sun': {'Tue': 'ENG101'}}
# Routine Details:
# Mon:
# Wed - CSE110
# Sun:
# Tue - ENG101
#
# ------------------------------
# Successfully dropped CSE110
# No such course in your routine
# ------------------------------
# ##################################
# Name: Harry
# Maximum Number of Courses: 4
# ...

# %%
class StudentRoutineGenerator :
  def __init__(self,n,c):
    self.n,self.c = n,c
    self.r = {'Sat/Thurs': {}, 'Sun/Tue': {}, 'Mon/Wed': {}}
    print(f"Name:{self.n}")
    print(f"Maximum Number of Courses:{self.c}")
    print(f"Initial Routine:{self.r}")
    self.count=0

  def addCourses(self,*data):
    for i in data:
      if self.count<self.c :
        a=i.split("-")
        for i,j in self.r.items():
          if i == a[1]:
           if a[0] not in j.values():
            if a[2] not in j :
             j[a[2]] = a[0]
            print(f"Successfully added",(a[0]),"!")
            self.count += 1
          else:
           print(f"Can't take {a[0]} It's clashing with your {j[a[2]]}")
      else:
            print(f"You already have {a[0]} in your routine")
    else:
        print(f"You can't take more than {self.c} courses")

  def showRoutine(self):
    print("Updated Routine:")
    print(self.r)
    print("Routine Details:")
    for i,j in self.r.items():
      if j!={}:
       print(i + ":")
      for a,b in j.items():
        print(f"{a} - (b)")

  def dropCourse(self,drop):
    c=0
    for i,j in self.r.items():
      if drop in j.values():
         for a,b in j.items():
           del j[a]
           c+=1
           print(f"Successfully dropped",{drop})
           break

    if c==0:
      print(f"No such course in your routine")


#driver_code
print('##################################')
st1 = StudentRoutineGenerator('Harry', 4)
print('------------------------------')
st1.addCourses('CSE110-Mon/Wed-12:30', 'MAT110-Mon/Wed-2:00')
st1.addCourses('ENG101-Sun/Tue-12:30', 'CSE110-Mon/Wed-9:30')
st1.addCourses('PHY111-Sun/Tue-12:30')
print('------------------------------')
st1.showRoutine()
print('------------------------------')
st1.dropCourse('CSE110')
st1.dropCourse('PHY112')
print('------------------------------')
st1.showRoutine()
print('##################################')
st2 = StudentRoutineGenerator('John', 3)
print('------------------------------')
st2.addCourses('MAT110-Mon/Wed-8:00')
st2.addCourses('ENG101-Sat/Thurs-12:30', 'CSE110-Sun/Tue-9:30')
st2.addCourses('PHY111-Sun/Tue-12:30')
print('------------------------------')
st2.showRoutine()

# %% [markdown]
# LAB-05-CLASSWORK

# %%
#TASK-01-CLASSWORK

class Student:
    def __init__(self, name, id, cgpa):
        self.name = name
        self.__id = id
        self.__cgpa = cgpa

    def getName(self):
        return self.name

    def getId(self):
        return self.__id

    def getCgpa(self):
        return self.__cgpa

    def setId(self, n_id):
        self.__id = n_id


class Department:
    def __init__(self, name):
        self.__name = name
        self.__std = []

    def addStudent(self, *students):
        for std in students:
            if std.getId() not in [i.getId() for i in self.__std]:
                self.__std.append(std)
                print(f"Welcome to {self.__name} department, {std.getName()}")
            else:
                print("Student with the same ID already exists, Please try with another ID")

    def findStudent(self, id):
        found = False
        for student in self.__std:
            if student.getId() == id:
                found = True
                print(f"Student info:\nStudent Name: {student.getName()}\nID: {student.getId()}\nCGPA: {student.getCgpa()}")
                break
        if not found:
            print("Student with this ID doesn't exist, Please give a valid ID")

    def details(self):
        print(f"Department Name: {self.__name}")
        print(f"Number of student: {len(self.__std)}")
        print("Details of the students:")
        for std in self.__std:
            print(f"Student name: {std.getName()}, ID: {std.getId()}, cgpa: {std.getCgpa()}")
#driver_code
s1 = Student("Akib", 22301010, 3.29)
s2 = Student("Reza", 22101010, 3.45)
s3 = Student("Ruhan", 23101934, 4.00)
print("1==================================")
cse = Department("CSE")
cse.findStudent(22112233)
print("2==================================")
cse.addStudent(s1,s2,s3)
print("3==================================")
cse.details()
print("4==================================")
cse.findStudent(22301010)
print("5==================================")
s4 = Student("Nakib",22301010,3.22)
cse.addStudent(s4)
print("6==================================")
s4.setId(21201220)
cse.addStudent(s4)
print("7==================================")
cse.details()
print("8==================================")
s5 = Student("Sakib",22201010,2.29)
cse.addStudent(s5)
print("9==================================")
cse.details()
# Out:
# 1==================================
# Student with this ID doesn't exist, Please give a valid ID
# 2==================================
# Welcome to CSE department, Akib
# Welcome to CSE department, Reza
# Welcome to CSE department, Ruhan
# 3==================================
# Department Name: CSE
# Number of student: 3
# Details of the students:
# Student name: Akib, ID: 22301010, cgpa: 3.29
# Student name: Reza, ID: 22101010, cgpa: 3.45
# Student name: Ruhan, ID: 23101934, cgpa: 4.0
# 4==================================
# Student info:
# Student Name: Akib
# ID: 22301010
# CGPA: 3.29
# 5==================================
# Student with the same ID already exists, Please try with another ID
# 6==================================
# Welcome to CSE department, Nakib
# 7==================================
# Department Name: CSE
# Number of student: 4
# Details of the students:
# Student name: Akib, ID: 22301010, cgpa: 3.29
# Student name: Reza, ID: 22101010, cgpa: 3.45
# ...

# %%
class Cargo:
    def __init__(self, c_name, c_weight):
        self.__name = c_name
        self.__weight = c_weight

    def getName(self):
        return self.__name

    def getWeight(self):
        return self.__weight


class Spaceship:
    def __init__(self, c_name, c_capacity):
        self.__name = c_name
        self.__capacity = c_capacity
        self.__crg_list = []
        self.__current_crg_w = 0

    def load_cargo(self, crg):
        if self.__current_crg_w + crg.getWeight() <= self.__capacity:
            self.__crg_list.append(crg.getName())
            self.__current_crg_w += crg.getWeight()
        else:
            print(f"Warning: Unable to load {crg.getName()} inside {self.__name}. Exceeds capacity by {self.__current_crg_w + crg.getWeight() - self.__capacity}.")

    def display_details(self):
        print(f"Spaceship Name: {self.__name}")
        print(f"Capacity: {self.__capacity}")
        print(f"Current Cargo Weight: {self.__current_crg_w}")
        print("Cargo:", self.__crg_list)


# Driver Code
falcon = Spaceship("Falcon", 50000)
apollo = Spaceship("Apollo", 100000)
enterprise = Spaceship("Enterprise", 220000)
print("1.===================================")

gold = Cargo("Gold", 45000)
platinum = Cargo("Platinum", 25000)
dilithium = Cargo("Dilithium", 50000)
trilithium = Cargo("Trilithium", 70000)
neutronium = Cargo("Neutronium", 80000)
print("2.===================================")

falcon.load_cargo(gold)
falcon.load_cargo(platinum)
falcon.display_details()
print("3.===================================")

apollo.load_cargo(gold)
apollo.display_details()
print("4.===================================")

falcon.load_cargo(neutronium)
print("5.===================================")

enterprise.load_cargo(dilithium)
enterprise.load_cargo(trilithium)
enterprise.load_cargo(neutronium)
enterprise.display_details()
# Out:
# 1.===================================
# 2.===================================
# ...
# Spaceship Name: Falcon
# Capacity: 50000
# Current Cargo Weight: 45000
# Cargo: ['Gold']
# 3.===================================
# Spaceship Name: Apollo
# Capacity: 100000
# Current Cargo Weight: 45000
# Cargo: ['Gold']
# 4.===================================
# ...
# 5.===================================
# Spaceship Name: Enterprise
# Capacity: 220000
# Current Cargo Weight: 200000
# Cargo: ['Dilithium', 'Trilithium', 'Neutronium']

# %% [markdown]
# LAB-05-TASK-HOMWEORK-Approach-1

# %%
class Book:
    def __init__(self, title, author, genre):
        self.__title = title
        self.__author = author
        self.__genre = genre
        self.__available = True
        self.__borrower = None

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

    def get_genre(self):
        return self.__genre

    def is_available(self):
        return self.__available

    def set_availability(self, availability):
        self.__available = availability

    def get_borrower(self):
        return self.__borrower

    def set_borrower(self, borrower):
        self.__borrower = borrower

    def display_info(self):
        print(f"Title: {self.__title}")
        print(f"Author: {self.__author}")
        print(f"Genre: {self.__genre}")
        print(f"Available: {self.__available}")


class LibraryMember:
    def __init__(self, name):
        self.__name = name
        self.__borrowed_books = []

    def get_name(self):
        return self.__name

    def borrow_book(self, book):
        if book.is_available():
            book.set_availability(False)
            book.set_borrower(self)
            self.__borrowed_books.append(book)
            print(f"{self.__name} has borrowed {book.get_title()}")
        else:
            print(f"{book.get_title()} is not available")

    def return_book(self, book):
        if book in self.__borrowed_books:
            book.set_availability(True)
            book.set_borrower(None)
            self.__borrowed_books.remove(book)
            print(f"{self.__name} has returned {book.get_title()}")
        else:
            print(f"{self.__name} did not borrow {book.get_title()}")

    def display_borrowed_books(self):
        print(f"{self.__name} has borrowed:")
        for book in self.__borrowed_books:
            print(book.get_title())


class Library:
    def __init__(self):
        self.books_available = []
        self.library_members = []

    def add_book(self, book):
        self.books_available.append(book)

    def add_library_member(self, member):
        self.library_members.append(member)

    def display_book_list(self):
        print("Books available in the library:")
        for book in self.books_available:
            book.display_info()
            print()

    def display_library_members(self):
        print("Library members:")
        for member in self.library_members:
            print(member.get_name())


# Driver code
library = Library()

book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", "Fiction")
book2 = Book("To Kill a Mockingbird", "Harper Lee", "Fiction")
book3 = Book("1984", "George Orwell", "Fiction")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

member1 = LibraryMember("Alice")
member2 = LibraryMember("Bob")

library.add_library_member(member1)
library.add_library_member(member2)

library.display_book_list()
library.display_library_members()

member1.borrow_book(book1)
member1.borrow_book(book2)
member2.borrow_book(book1)

member1.display_borrowed_books()
member2.display_borrowed_books()

member1.return_book(book1)

member2.borrow_book(book1)

member1.display_borrowed_books()
member2.display_borrowed_books()
# Out:
# Books available in the library:
# Title: The Great Gatsby
# Author: F. Scott Fitzgerald
# Genre: Fiction
# Available: True
#
# Title: To Kill a Mockingbird
# Author: Harper Lee
# Genre: Fiction
# Available: True
#
# Title: 1984
# Author: George Orwell
# Genre: Fiction
# Available: True
#
# Library members:
# Alice
# Bob
# Alice has borrowed The Great Gatsby
# Alice has borrowed To Kill a Mockingbird
# The Great Gatsby is not available
# Alice has borrowed:
# The Great Gatsby
# To Kill a Mockingbird
# Bob has borrowed:
# Alice has returned The Great Gatsby
# Bob has borrowed The Great Gatsby
# Alice has borrowed:
# To Kill a Mockingbird
# Bob has borrowed:
# The Great Gatsby

# %% [markdown]
# LAB-05-TASK-HOMWEORK-Approach-2

# %%
class Book:
    def __init__(self, title, author, genre):
        self.__title = title
        self.__author = author
        self.__genre = genre
        self.__available = True
        self.__borrower = None

    def set_title(self, title):
        self.__title = title

    def get_title(self):
        return self.__title

    def set_author(self, author):
        self.__author = author

    def get_author(self):
        return self.__author

    def set_genre(self, genre):
        self.__genre = genre

    def get_genre(self):
        return self.__genre

    def set_availability(self, available):
        self.__available = available

    def get_availability(self):
        return self.__available

    def set_borrower(self, borrower):
        self.__borrower = borrower

    def get_borrower(self):
        return self.__borrower

    def display_info(self):
        print(f"Title: {self.title}\nAuthor: {self.author}\nGenre: {self.genre}\nAvailable: {self.available}\nBorrowed by: {self.borrower}\n-----")


class LibraryMember:
    def __init__(self, member_id, name):
        self.__member_id = member_id
        self.__name = name
        self.__borrowed_books = []

    def set_member_id(self, member_id):
        self.__member_id = member_id

    def get_member_id(self):
        return self.__member_id

    def set_name(self, name):
        self.__name = name

    def get_name(self):
        return self.__name

    def borrow_book(self, book):
        if book.get_availability():
            book.set_availability(False)
            book.set_borrower(self)
            self.__borrowed_books.append(book)
            print(f" '{book.get_title()}' borrowed by: {self.get_name()}.")
        else:
            print(f"The book '{book.get_title()}'not available")

    def return_book(self, book):
        if book in self.__borrowed_books:
            book.set_availability(True)
            book.set_borrower(None)
            self.__borrowed_books.remove(book)
            print(f"'{book.get_title()}' returned by: {self.get_name()}.")
        else:
            print(f"{self.get_name()} did not borrow the book '{book.get_title()}'.")

    def display_borrowed_books(self):
        if len(self.__borrowed_books) == 0:
            print(f"{self.get_name()} did not borrow.")
            return
        print(f"{self.get_name()} has borrowed the following books:")
        for book in self.__borrowed_books:
            print(f"- {book.get_title()}")


class Library:
    def __init__(self):
        self.books_available = []
        self.library_members = []

    def add_book(self, book):
      if type(book).__name__ == 'Book':
          self.books_available.append(book)
          print(f"The book '{book.get_title()}' has been added to the library collection.")
      else:
          print("Invalid input.")

    def add_library_member(self, member):
      if type(member).__name__ == 'LibraryMember':
          self.library_members.append(member)
          print(f"{member.get_name()} has been added as a library member.")
      else:
          print("Invalid input.")

    def display_book_list(self):
      if len(self.books_available) == 0:
          print("No book available.")
          return
      print("There are the following books available:")
      for book in self.books_available:
          print(f"- {book.get_title()}")

    def display_library_members(self):
      if len(self.library_members) == 0:
          print("There are no members.")
          return
      print("There are the following members:")
      for member in self.library_members:
          print(f"- {member.get_name()}")
      print(f"- {member.get_name()}")




# Create a Library object
my_library = Library()
print("-----------------------------------------------")

# Create some Book objects
print("----------------------------------------------")
book1 = Book("Deyal", "Humayun Ahmed", "Historical")
book2 = Book("Kalbela", "Samaresh Majumder", "Political")
book3 = Book("Tukunjil", "Muhammad Jafar Iqbal", "Science Fiction")

# Add books to the library
print("---------------------------------------------")
my_library.add_book(book1)
my_library.add_book(book2)
my_library.add_book(book3)

# Display the list of books in the library
print("--------------------------------------------")
my_library.display_book_list()

# Create some LibraryMember objects
print("--------------------------------------------")
member1 = LibraryMember("Member-01", "TASNIM")
member2 = LibraryMember("Member-02", "SAZZAD")


# Add members to the library
print("--------------------------------------------")
my_library.add_library_member(member1)
my_library.add_library_member(member2)

# Display the list of library members
print("-------------------------------------------")
my_library.display_library_members()

# Borrow some books
print("-------------------------------------------")
member1.borrow_book(book1)
member1.borrow_book(book2)
member2.borrow_book(book3)

# Display borrowed books
print("-------------------------------------------")
member1.display_borrowed_books()
member2.display_borrowed_books()

# Return some books
print("-------------------------------------------")
member1.return_book(book1)
member2.return_book(book3)

# Display borrowed books again
print("-------------------------------------------")
member1.display_borrowed_books()
member2.display_borrowed_books()
# Out:
# -----------------------------------------------
# ----------------------------------------------
# ---------------------------------------------
# The book 'Deyal' has been added to the library collection.
# The book 'Kalbela' has been added to the library collection.
# The book 'Tukunjil' has been added to the library collection.
# --------------------------------------------
# There are the following books available:
# - Deyal
# - Kalbela
# - Tukunjil
# --------------------------------------------
# --------------------------------------------
# TASNIM has been added as a library member.
# SAZZAD has been added as a library member.
# -------------------------------------------
# There are the following members:
# - TASNIM
# - SAZZAD
# - SAZZAD
# -------------------------------------------
#  'Deyal' borrowed by: TASNIM.
#  'Kalbela' borrowed by: TASNIM.
#  'Tukunjil' borrowed by: SAZZAD.
# -------------------------------------------
# TASNIM has borrowed the following books:
# ...

# %% [markdown]
# LAB-06-CLASSWORK

# %%
#TASK-01-CLASSWORK

class NikeBangladesh:
    all_branches = []
    all_inventory = {'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}
    total_sold = 0

    def __init__(self, brnch_name):
        self.brnch_name = brnch_name
        self.inventory = {'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}
        self.sold = 0
        self.__class__.all_branches.append(self.brnch_name)

    def details(self):
        print(f"{self.brnch_name} outlet:\nProducts Currently Stocked:")
        print(self.inventory)
        print(f"Sold: {self.sold}")

    def restockProducts(self, restk_dict):
        for prod, quant in restk_dict.items():
            self.inventory[prod] += quant
            self.__class__.all_inventory[prod] += quant

    def productSold(self, sell_dict):
        for prod, quant in sell_dict.items():
            self.inventory[prod] -= quant
            self.sold += quant
            self.__class__.all_inventory[prod] -= quant
            self.__class__.total_sold += quant

    @classmethod
    def status(cls):
        print("Nike Bangladesh Status:")
        print(f"Branches Opened: {cls.all_branches}")
        print("Currently Stocked")
        print(cls.all_inventory)
        print(f"Sold: {cls.total_sold}")


# Driver code
if __name__ == "__main__":
    print("xxxxxxxxxxxxxx1xxxxxxxxxxxxxxxx")
    NikeBangladesh.status()
    dhaka = NikeBangladesh("Dhaka Banani")
    chittagong = NikeBangladesh("Chittagong GEC")
    print("xxxxxxxxxxxxxx2xxxxxxxxxxxxxxxx")
    dhaka.details()
    print("xxxxxxxxxxxxxx3xxxxxxxxxxxxxxxx")
    chittagong.details()
    print("xxxxxxxxxxxxxx4xxxxxxxxxxxxxxxx")
    dhaka.restockProducts(
        {"Air Jordan": 1200, "Cortez": 200, "Zoom Kobe": 200}
    )
    chittagong.restockProducts(
        {"Air Jordan": 1000, "Cortez": 250, "Zoom Kobe": 100}
    )
    print("xxxxxxxxxxxxxx5xxxxxxxxxxxxxxxx")
    NikeBangladesh.status()
    print("xxxxxxxxxxxxxx6xxxxxxxxxxxxxxxx")
    dhaka.productSold({"Air Jordan": 760, "Cortez": 90})
    chittagong.productSold({"Air Jordan": 520, "Zoom Kobe": 70})
    print("xxxxxxxxxxxxxx7xxxxxxxxxxxxxxxx")
    NikeBangladesh.status()
# Out:
# xxxxxxxxxxxxxx1xxxxxxxxxxxxxxxx
# Nike Bangladesh Status:
# Branches Opened: []
# Currently Stocked
# {'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}
# Sold: 0
# xxxxxxxxxxxxxx2xxxxxxxxxxxxxxxx
# Dhaka Banani outlet:
# Products Currently Stocked:
# {'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}
# Sold: 0
# xxxxxxxxxxxxxx3xxxxxxxxxxxxxxxx
# Chittagong GEC outlet:
# Products Currently Stocked:
# {'Air Jordan': 0, 'Cortez': 0, 'Zoom Kobe': 0}
# Sold: 0
# xxxxxxxxxxxxxx4xxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxx5xxxxxxxxxxxxxxxx
# Nike Bangladesh Status:
# Branches Opened: ['Dhaka Banani', 'Chittagong GEC']
# Currently Stocked
# {'Air Jordan': 2200, 'Cortez': 450, 'Zoom Kobe': 300}
# Sold: 0
# xxxxxxxxxxxxxx6xxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxx7xxxxxxxxxxxxxxxx
# Nike Bangladesh Status:
# Branches Opened: ['Dhaka Banani', 'Chittagong GEC']
# Currently Stocked
# {'Air Jordan': 920, 'Cortez': 360, 'Zoom Kobe': 230}
# Sold: 1440

# %%
#TASK-2-CLASSWORK
class Question:
    def __init__(self, text, choices, correct_choice):
        self.text = text
        self.choices = choices
        self.correct_choice = correct_choice


class Quiz:

    total_quiz = 0


    def __init__(self, quiz_name):
        self.name = quiz_name
        self.questions = []
        self.score = 0
        self.__class__.total_quiz += 1


    def add_question(self, *questions):
      for question in questions:
            self.questions.append(question)

    @classmethod
    def create_from_data(cls, quiz_name, question_data_list):
      quiz = cls(quiz_name)
      for question_data in question_data_list:
            question = Question(question_data['text'], question_data['choices'], question_data['correct_choice'])
            quiz.add_question(question)
      return quiz



    def attempt(self):
      '''
      Sample printing format for attempt method.
      let's say we are calling quiz1.attempt() from the driver code.
      output:

      --- Math Quiz ---
      What is the result of 2 + 2?
      1. 3
      2. 4
      3. 5
      Your answer (enter the choice number): 2
      Correct answer! 1 point for you.
      What is the result of 3 * 6?
      1. 15
      2. 18
      3. 20
      Your answer (enter the choice number): 1
      Wrong answer!
      Your total score: 1/2
      '''
      print(f"--- {self.name} ---")

      for question in self.questions:
        print(f"{question.text}") # will print the question as shown in the output.
        for index in range(len(question.choices)):# this loop will print the choices as shown in the output.
            print(f"{index+1}. {question.choices[index]}")

        user_choice = int(input("Your answer (enter the choice number): ")) # takes the choice number from the user

        if user_choice == question.correct_choice: # calculate the quiz score
            self.score += 1
            print("Correct answer! 1 point for you.")
        else:
          print("Wrong answer!")
      print(f"Your total score: {self.score}/{len(self.questions)}") # total score gained in a quiz

# Test the Quiz Maker

# We are creating a Quiz object for the Math Quiz
quiz1 = Quiz("Math Quiz")
# Now creating two quiz question objects
# The Question class constructor takes three parameters: (Question, choices, correct answer)
# The correct answer is given as (list_index + 1)
quiz1_question1 = Question("What is the result of 2 + 2?", ["3", "4", "5"], 2)
quiz1_question2 = Question("What is the result of 3 * 6?", ["15", "18", "20"], 2)
# Adding the question objects to a question list of the Quiz class
quiz1.add_question(quiz1_question1, quiz1_question2)
# We will use this list of dictionaries to prepare the python quiz questions
python_quiz_data = [
    {
        'text': "What is the keyword to define a function in Python?",
        'choices': ["func", "def", "function"],
        'correct_choice': 2
    },
    {
        'text': "Which one is NOT a built-in data type in Python?",
        'choices': ["int", "str", "double"],
        'correct_choice': 3
    }
]
# Create another Quiz class object for the python quiz
quiz2 = Quiz.create_from_data("Python Quiz", python_quiz_data)
# Accessing static variable using the class name
print("Total no. of quizzes: ", Quiz.total_quiz)
# Attempt Math Quiz
quiz1.attempt()
# Attempt Python Quiz
quiz2.attempt()
# Out:
# Total no. of quizzes:  2
# --- Math Quiz ---
# What is the result of 2 + 2?
# 1. 3
# 2. 4
# 3. 5
# Your answer (enter the choice number): 2
# Correct answer! 1 point for you.
# What is the result of 3 * 6?
# 1. 15
# 2. 18
# 3. 20
# Your answer (enter the choice number): 2
# Correct answer! 1 point for you.
# Your total score: 2/2
# --- Python Quiz ---
# What is the keyword to define a function in Python?
# 1. func
# 2. def
# 3. function
# Your answer (enter the choice number): 2
# Correct answer! 1 point for you.
# Which one is NOT a built-in data type in Python?
# 1. int
# 2. str
# 3. double
# Your answer (enter the choice number): 3
# Correct answer! 1 point for you.
# Your total score: 2/2

# %%
class Foodiz:

    total_sell = 0
    branch_info = []

    def __init__(self, branch_name):
        self.branch_name = branch_name
        self.branch_sell = 0
        Foodiz.branch_info.append(self)

    def sell_quantity(self, quantity):
        self.branch_sell = quantity * 300
        Foodiz.total_sell += self.branch_sell

    def branch_information(self):
        print(f"Branch Name: {self.branch_name}\nBranch Sell: {self.branch_sell} Taka")

    @classmethod
    def details(cls):
        print(f"Total Number of branch(s): {len(cls.branch_info)}")
        print(f"Total Sell: {cls.total_sell} Taka")
        print("########################")
        for branch in cls.branch_info:
            print(f"Branch Name: {branch.branch_name}")
            print(f"Branch Sell: {branch.branch_sell} Taka")
            if cls.total_sell > 0:
                contribution = (branch.branch_sell / cls.total_sell)*100
            else:
              0
            print(f"Branch consists of total sell's: {contribution:}%")
            print("########################")

# Driver code
Foodiz.details()
print('1----------------------------------')
mohakhali = Foodiz('Mohakhali')
mohakhali.sell_quantity(25)
mohakhali.branch_information()
print('2----------------------------------')
Foodiz.details()
print('3========================')
banani = Foodiz('Banani')
banani.sell_quantity(15)
banani.branch_information()
print('4----------------------------------')
Foodiz.details()
print('5========================')
gulshan = Foodiz('Gulshan')
gulshan.sell_quantity(9)
gulshan.branch_information()
print('6----------------------------------')
Foodiz.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
# ########################
# 1----------------------------------
# Branch Name: Mohakhali
# Branch Sell: 7500 Taka
# 2----------------------------------
# Total Number of branch(s): 1
# Total Sell: 7500 Taka
# ########################
# Branch Name: Mohakhali
# Branch Sell: 7500 Taka
# Branch consists of total sell's: 100.0%
# ########################
# 3========================
# Branch Name: Banani
# Branch Sell: 4500 Taka
# 4----------------------------------
# Total Number of branch(s): 2
# Total Sell: 12000 Taka
# ########################
# Branch Name: Mohakhali
# Branch Sell: 7500 Taka
# Branch consists of total sell's: 62.5%
# ########################
# Branch Name: Banani
# Branch Sell: 4500 Taka
# Branch consists of total sell's: 37.5%
# ########################
# 5========================
# Branch Name: Gulshan
# Branch Sell: 2700 Taka
# 6----------------------------------
# Total Number of branch(s): 3
# ...

# %% [markdown]
# LAB-06-HOMEWORK

# %%
class Movie:
    def __init__(self, name, genre, duration):
        self.name = name
        self.genre = genre
        self.duration = duration

    def movieInfo(self):
        return f"Name: {self.name}, Genre: {self.genre}, Duration: {self.duration} minutes"

    @classmethod
    def createMovie_fromString(cls, movie_string):
        name, genre, duration = movie_string.split('-')
        return cls(name, genre, int(duration))


class StarCinema:
    all_branch_info = {}

    def __init__(self, branch_name):
        self.branch_name = branch_name
        self.movie_list = []
        StarCinema.all_branch_info[branch_name] = self.movie_list

    def addMovies(self, *movie_objects):
        for movie in movie_objects:
            if movie not in self.movie_list:
                self.movie_list.append(movie)

    def removeMovie(self, movie_object):
        if movie_object in self.movie_list:
            self.movie_list.remove(movie_object)


    @classmethod
    def check(cls, movie_name):
       found = False
       for branch_name in cls.all_branch_info:
        movie_list = cls.all_branch_info[branch_name]
        for movie in movie_list:
            if movie.name == movie_name:
                print(f"Movie '{movie_name}' is streaming at {branch_name} branch.")
                print(movie.movieInfo())
                found = True
        if not found:
           print(f"Movie '{movie_name}' is not streaming in any branch.")

    @classmethod
    def showAllBranchInfo(cls):
      for branch_name in cls.all_branch_info:
        movie_list = cls.all_branch_info[branch_name]
        print(f"Branch Name: {branch_name}")
        mov_num = 1  # Manual index counter
        for movie in movie_list:
            print(f"Movie No: {mov_num}")
            print(movie.movieInfo())
            print('-' * 30)
            mov_num += 1  # Increment the counter



#driver code
# Creating Movie objects from string data
movies = [
    Movie.createMovie_fromString('Amar Ache Jol-Drama-150'),
    Movie.createMovie_fromString('Bumblebee-Adventure-168'),
    Movie.createMovie_fromString('Feluda-Detective-149'),
    Movie.createMovie_fromString('Pother Pachali-Drama-90')
]

# Creating StarCinema branch objects
gulshan_branch = StarCinema('Gulshan')
banani_branch = StarCinema('Banani')

# Adding movies to branches
gulshan_branch.addMovies(movies[0], movies[1])
banani_branch.addMovies(movies[0], movies[2], movies[3])

# Showing initial branch information
print("Previous Branch Information:")
StarCinema.showAllBranchInfo()

# Checking which branches a movie is streaming in
StarCinema.check('Amar Ache Jol')
StarCinema.check('Feluda')
StarCinema.check('Bumblebee')
StarCinema.check('Pother Pachali')

# Removing a movie from a branch
gulshan_branch.removeMovie(movies[0])

# Showing updated branch information
print("\nNewly Updated Branch Info:")
StarCinema.showAllBranchInfo()
# Out:
# Previous Branch Information:
# Branch Name: Gulshan
# Movie No: 1
# Name: Amar Ache Jol, Genre: Drama, Duration: 150 minutes
# ------------------------------
# Movie No: 2
# Name: Bumblebee, Genre: Adventure, Duration: 168 minutes
# ------------------------------
# Branch Name: Banani
# Movie No: 1
# Name: Amar Ache Jol, Genre: Drama, Duration: 150 minutes
# ------------------------------
# Movie No: 2
# Name: Feluda, Genre: Detective, Duration: 149 minutes
# ------------------------------
# Movie No: 3
# Name: Pother Pachali, Genre: Drama, Duration: 90 minutes
# ------------------------------
# Movie 'Amar Ache Jol' is streaming at Gulshan branch.
# Name: Amar Ache Jol, Genre: Drama, Duration: 150 minutes
# Movie 'Amar Ache Jol' is streaming at Banani branch.
# Name: Amar Ache Jol, Genre: Drama, Duration: 150 minutes
# Movie 'Feluda' is not streaming in any branch.
# Movie 'Feluda' is streaming at Banani branch.
# Name: Feluda, Genre: Detective, Duration: 149 minutes
# ...

# %% [markdown]
# LAB-07-CLASSWORK

# %%
#TASK-1-CLASSWORK

class KK_tea:
    total_sales = {}

    def __init__(self, price, tea_bags=50):
        self.name = "KK Regular Tea"
        self.weight = tea_bags * 2
        self.tea_bags = tea_bags
        self.price = price
        self.status = False

    def product_detail(self):
        print(f"Name: {self.name}, Weight: {self.weight}\nTea Bags: {self.tea_bags}, Price: {self.price}\nStatus: {self.status}")

    @classmethod
    def show_total_sales(cls):
        print("Total sales:", cls.total_sales)

    @classmethod
    def update_sold_status_regular(cls, *objects):
        for obj in objects:
            obj.status = True
            cls.total_sales[obj.name] = cls.total_sales.get(obj.name, 0) + 1


class KK_flavoured_tea(KK_tea):
    def __init__(self, flavor, price, tea_bags=50):
        super().__init__(price, tea_bags)
        self.name = f"KK {flavor} Tea"

    @classmethod
    def update_sold_status_flavoured(cls, *objects):
        for obj in objects:
            obj.status = True
            cls.total_sales[obj.name] = cls.total_sales.get(obj.name, 0) + 1


t1 = KK_tea(250)
print("-----------------1-----------------")
t1.product_detail()
print("-----------------2-----------------")
KK_tea.show_total_sales()
print("-----------------3-----------------")
t2 = KK_tea(470, 100)
t3 = KK_tea(360, 75)
KK_tea.update_sold_status_regular(t1, t2, t3)
print("-----------------4-----------------")
t3.product_detail()
print("-----------------5-----------------")
KK_tea.show_total_sales()
print("-----------------6-----------------")
t4 = KK_flavoured_tea("Jasmine", 260, 50)
t5 = KK_flavoured_tea("Honey Lemon", 270, 45)
t6 = KK_flavoured_tea("Honey Lemon", 270, 45)
print("-----------------7-----------------")
t4.product_detail()
print("-----------------8-----------------")
t6.product_detail()
print("-----------------9-----------------")
KK_flavoured_tea.update_sold_status_flavoured(t4, t5, t6)
print("-----------------10-----------------")
KK_tea.show_total_sales()
# Out:
# -----------------1-----------------
# Name: KK Regular Tea, Weight: 100
# Tea Bags: 50, Price: 250
# Status: False
# -----------------2-----------------
# Total sales: {}
# -----------------3-----------------
# -----------------4-----------------
# Name: KK Regular Tea, Weight: 150
# Tea Bags: 75, Price: 360
# Status: True
# -----------------5-----------------
# Total sales: {'KK Regular Tea': 3}
# -----------------6-----------------
# -----------------7-----------------
# Name: KK Jasmine Tea, Weight: 100
# Tea Bags: 50, Price: 260
# Status: False
# -----------------8-----------------
# Name: KK Honey Lemon Tea, Weight: 90
# Tea Bags: 45, Price: 270
# Status: False
# -----------------9-----------------
# -----------------10-----------------
# Total sales: {'KK Regular Tea': 3, 'KK Jasmine Tea': 1, 'KK Honey Lemon Tea': 2}

# %%
#TASK-2-CLASSWORK

import math

class TwoDVector:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    def add2DVectors(self, *vectors):
        for i in vectors:
            self.__x += i.__x
            self.__y += i.__y

    def print2DVector(self):
        if self.__y >= 0:
            y = "+ " + str(self.__y)
        else:
            y = str(self.__y)
        print(f"{self.__x}i {y}j")


class ThreeDVector(TwoDVector):
    def __init__(self, x, y, z):
        super().__init__(x, y)
        self.__z = z

    def add3DVectors(self, *vectors):
        for i in vectors:
            self.add2DVectors(i)  # Reusing the add2DVectors() method from TwoDVector
            self.__z += i.__z

    def multiplyScalar(self, scalar):
        self._TwoDVector__x *= scalar  # Accessing private variable using name mangling
        self._TwoDVector__y *= scalar
        self.__z *= scalar

    def calculateLength(self):
        return math.sqrt(self._TwoDVector__x**2 + self._TwoDVector__y**2 + self.__z**2)

    def print3DVector(self):
        if self._TwoDVector__y >= 0:
            y = "+ " + str(self._TwoDVector__y)
        else:
            y = str(self._TwoDVector__y)
        if self.__z >= 0:
            z = "+ " + str(self.__z)
        else:
            z = str(self.__z)
        print(f"{self._TwoDVector__x}i {y}j {z}k")


TwoDV1 = TwoDVector(5, 6)
TwoDV2 = TwoDVector(3, 7)
TwoDV3 = TwoDVector(1, 8)
print("===============")
TwoDV1.add2DVectors(TwoDV2, TwoDV3)
TwoDV1.print2DVector()
print("===============")

class ThreeDVector(TwoDVector):  # Re-declare the class name
    def __init__(self, x, y, z):
        super().__init__(x, y)
        self.__z = z

    def add3DVectors(self, *vectors):
        for i in vectors:
            self.add2DVectors(i)  # Reusing the add2DVectors() method from TwoDVector
            self.__z += i.__z

    def multiplyScalar(self, scalar):
        self._TwoDVector__x *= scalar  # Accessing private variable using name mangling
        self._TwoDVector__y *= scalar
        self.__z *= scalar

    def calculateLength(self):
        return math.sqrt(self._TwoDVector__x**2 + self._TwoDVector__y**2 + self.__z**2)

    def print3DVector(self):
        if self._TwoDVector__y >= 0:
            y = "+ " + str(self._TwoDVector__y)
        else:
            y = str(self._TwoDVector__y)
        if self.__z >= 0:
            z = "+ " + str(self.__z)
        else:
            z = str(self.__z)
        print(f"{self._TwoDVector__x}i {y}j {z}k")

TwoDV1 = TwoDVector(5, 6)
TwoDV2 = TwoDVector(3, 7)
TwoDV3 = TwoDVector(1, 8)
print("===============")
TwoDV1.add2DVectors(TwoDV2, TwoDV3)
TwoDV1.print2DVector()
print("===============")
ThreeDV1 = ThreeDVector(5, 6, 1)
ThreeDV2 = ThreeDVector(1, 9, -7)
ThreeDV3 = ThreeDVector(8, 2, 4)
print("===============")
ThreeDV1.add3DVectors(ThreeDV2,ThreeDV3)
ThreeDV1.print3DVector()
print("===============")
ThreeDV1.multiplyScalar(3)
ThreeDV1.print3DVector()
print("===============")
print(ThreeDV1.calculateLength())
# Out:
# ...
# 9i + 21j
# ...
# 9i + 21j
# ...
# 14i + 17j -2k
# ...
# 42i + 51j -6k
# ...
# 66.34003316248794

# %%
#TASK-3-CLASSWORK

class File:

    files_directory = []

    def __init__(self, name, size, date_of_creation):

        self.name = name
        self.size = size
        self.date_of_creation = date_of_creation
        self.description = ''
        File.files_directory.append(self)

    def renameFile(self, n):
        self.name = n

    def updateDescription(self, txt):
        self.description = txt

    def previewFile(self):
        print(f"Name of file: {self.name}")
        print(f"Description: {self.description}")
        print(f"Size: {self.size}")
        print(f"Date created: {self.date_of_creation}")

    @classmethod
    def previewAllFiles(cls):
        for file in cls.files_directory:
            file.previewFile()
            print("==========")

class Audio(File):

    def __init__(self, name, size, date_of_creation, duration, lyrics=None):
        super().__init__(name, size, date_of_creation)
        self.duration = duration
        self.lyrics = lyrics

    def playAudio(self):
        self.previewFile()
        if self.lyrics:
            for key, value in self.lyrics.items():
                print(f"{key}: {value}")
            print("==========")
        else:
            print("No lyrics available.")
            print("==========")

class Image(File):

    def __init__(self, name, size, date_of_creation, dimensions):
        super().__init__(name, size, date_of_creation)
        self.width, self.height = map(int, dimensions.split('x'))

    def displayPicture(self):
        self.previewFile()
        print(f"Dimensions: {self.width} x {self.height}")
        print("==========")

print("----------1----------")
text_file = File("New file", "2 MB", "19 July 2020")
binary_file = File("Bin", "100 Kb", "20 August 2021")
print("----------2----------")
text_file.previewFile()
print("----------3----------")
audio_file1 = Audio("Class recording", "258 MB", "13th february 2023", "2 hours")
print("----------4----------")
audio_file1.updateDescription("Contains recordings of the CSE dept CSE111 Class")
print("----------5----------")
audio_file1.previewFile()
print("----------6----------")
audio_file1.playAudio()
print("----------7----------")

lyric = {'0:00-0:05': "I have been reading books of old",
         '0:06-0:10': "The legends and the myths",
         '0:11-0:15': "Achilles and his gold",
         '0:16-0:20': "Hercules and his gifts",
         '0:21-0:25': "Spider Man's control",
         '0:26-0:30': "And Batman with his fists",
         '0:31-0:35': "And clearly I don't see myself upon that list"}

print("----------8----------")
audio_file2 = Audio("The squeeze podcast", "200 MB", "17th July 2023", "35 seconds", lyric)
print("----------9----------")
audio_file2.playAudio()
print("----------10----------")
image_file1 = Image("name", "2MB", "31st July", "10x5")
print("----------11----------")
image_file1.displayPicture()
print("----------12----------")
File.previewAllFiles()
# Out:
# ----------1----------
# ----------2----------
# Name of file: New file
# Description:
# Size: 2 MB
# Date created: 19 July 2020
# ----------3----------
# ----------4----------
# ----------5----------
# Name of file: Class recording
# Description: Contains recordings of the CSE dept CSE111 Class
# Size: 258 MB
# Date created: 13th february 2023
# ----------6----------
# Name of file: Class recording
# Description: Contains recordings of the CSE dept CSE111 Class
# Size: 258 MB
# Date created: 13th february 2023
# No lyrics available.
# ...
# ----------7----------
# ----------8----------
# ----------9----------
# Name of file: The squeeze podcast
# Description:
# Size: 200 MB
# Date created: 17th July 2023
# 0:00-0:05: I have been reading books of old
# 0:06-0:10: The legends and the myths
# 0:11-0:15: Achilles and his gold
# 0:16-0:20: Hercules and his gifts
# 0:21-0:25: Spider Man's control
# 0:26-0:30: And Batman with his fists
# 0:31-0:35: And clearly I don't see myself upon that list
# ...

# %% [markdown]
# LAB-07-HOMEWORK

# %%
#HOMEWORK-LAB-7-CSE111

class Employee:
    employee_count = {'Programmer': 0, 'HR': 0}

    def __init__(self, name, joining_date, work_experience, weekly_work_hour=40):
        self.name = name
        self.joining_date = joining_date
        self.work_experience = work_experience
        if weekly_work_hour > 60:
            print('Error: Invalid weekly work hour. Setting to default value of 40.')
            self.weekly_work_hour = 40
        else:
            self.weekly_work_hour = weekly_work_hour

    @classmethod
    def showDetails(cls):
       total_employees = 0
       for key in cls.employee_count:
        total_employees += cls.employee_count[key]
        print(f'Total Employee/s : {total_employees}')
       for employee_type, count in cls.employee_count.items():
          print(f'Total {employee_type}/s: {count}')


class Programmer(Employee):
    designation_list = ['Junior Software Engineer', 'Software Engineer', 'Senior Software Engineer', 'Technical Lead']

    def __init__(self, name, joining_date, work_experience, weekly_work_hour=40):
        super().__init__(name, joining_date, work_experience, weekly_work_hour)
        self.id = self.createProgrammerID()
        if work_experience < 3:
            self.designation = 'Junior Software Engineer'
        elif work_experience < 5:
            self.designation = 'Software Engineer'
        elif work_experience < 8:
            self.designation = 'Senior Software Engineer'
        else:
            self.designation = 'Technical Lead'
        Employee.employee_count['Programmer'] += 1

    def showProgrammerDetails(self):
        print(f'Name: {self.name}')
        print(f'ID: {self.id}')
        print(f'Joining Date: {self.joining_date}')
        print(f'Designation: {self.designation}')
        print(f'Salary: {self.calculateSalary()}')

    def calculateSalary(self):
        base_salary_dict = {
            'Junior Software Engineer': 30000,
            'Software Engineer': 45000,
            'Senior Software Engineer': 70000,
            'Technical Lead': 120000
        }
        base_salary = base_salary_dict[self.designation]
        years_in_company = (2023 - int(self.joining_date[:4]))
        salary = base_salary * (1.15 ** years_in_company)
        return salary

    def createProgrammerID(self):
       total_employee_count = 0
       for key in Employee.employee_count:
        total_employee_count += Employee.employee_count[key]
        id_str = f'P-{self.joining_date[2:]}-{total_employee_count}'
        return id_str


    def calculateOvertime(self):
        overtime_hours = max(0, self.weekly_work_hour - 40)
        overtime_pay_per_month = overtime_hours * 500 * 4
        return overtime_pay_per_month

class HR(Employee):
    def __init__(self, name, joining_date, work_experience, weekly_work_hour=40):
        super().__init__(name, joining_date, work_experience, weekly_work_hour)
        self.id = self.createHREmployeeID()
        Employee.employee_count['HR'] += 1

    def createHREmployeeID(self):
        total_employee_count = Employee.employee_count['HR']
        id_str = f'HR-{self.joining_date[2:]}-{total_employee_count}'
        return id_str

    def showHREmployeeDetails(self):
        print(f'Name: {self.name}')
        print(f'ID: {self.id}')
        print(f'Joining Date: {self.joining_date}')

class InternProgrammer(Programmer):
    intern_count = 0

    def __init__(self, name, joining_date, intern_type):
        super().__init__(name, joining_date, 0, 40)
        self.temp_id = self.generate_temp_id()
        self.intern_type = intern_type
        self.status = self.calculate_status()
        self.increment_intern_count()

    def increment_intern_count(self):
        InternProgrammer.intern_count += 1

    def generate_temp_id(self):
        return f'Temp_{InternProgrammer.intern_count}'

    def calculate_status(self):
        months_in_company = (8 - int(self.joining_date[5:7])) + (2023 - int(self.joining_date[:4])) * 12
        return months_in_company >= 4

    def showInternDetails(self):
        print(f'Name: {self.name}')
        print(f'Temporary ID: {self.temp_id}')
        print(f'Joining Date: {self.joining_date}')
        print(f'Intern Type: {self.intern_type}')
        print(f'Eligible for Promotion: {self.status}')

    def promoteToProgrammer(self):
        if self.status:
            print("The intern is promoted!")
            return Programmer(self.name, '2023-08-16', 0, 40)
        else:
            print("The intern cannot be promoted.")

#DRIVER CODE

# Creating instances of different employees
prog1 = Programmer('Alice', '2009-01-01', 2)
prog2 = Programmer('Bob', '2012-06-01', 5)
prog3 = Programmer('Charlie', '2015-03-15', 10)

hr1 = HR('David', '2014-12-10', 6)
hr2 = HR('Eva', '2021-02-20', 3)

intern1 = InternProgrammer('Frank', '2018-01-01', 'Paid')
intern2 = InternProgrammer('Grace', '2003-07-01', 'Unpaid')

# Display details of different employees
print("###################### Programmer Details ######################")
prog1.showProgrammerDetails()
prog2.showProgrammerDetails()
prog3.showProgrammerDetails()

print("###################### HR Employee Details ######################")
hr1.showHREmployeeDetails()
hr2.showHREmployeeDetails()

print("###################### Intern Programmer Details ######################")
intern1.showInternDetails()
intern2.showInternDetails()

# Promote intern to programmer and display details
promoted_programmer = intern1.promoteToProgrammer()
if promoted_programmer:
    print("###################### Promoted Programmer Details ######################")
    promoted_programmer.showProgrammerDetails()

# Display total employee counts
print("###################### Employee Count  ######################")
Employee.showDetails()
# Out:
# ###################### Programmer Details ######################
# Name: Alice
# ID: P-09-01-01-0
# Joining Date: 2009-01-01
# Designation: Junior Software Engineer
# Salary: 212271.17293466927
# Name: Bob
# ID: P-12-06-01-1
# Joining Date: 2012-06-01
# Designation: Senior Software Engineer
# Salary: 325667.3977244865
# Name: Charlie
# ID: P-15-03-15-2
# Joining Date: 2015-03-15
# Designation: Technical Lead
# Salary: 367082.74350468727
# ###################### HR Employee Details ######################
# Name: David
# ID: HR-14-12-10-0
# Joining Date: 2014-12-10
# Name: Eva
# ID: HR-21-02-20-1
# Joining Date: 2021-02-20
# ###################### Intern Programmer Details ######################
# Name: Frank
# Temporary ID: Temp_0
# Joining Date: 2018-01-01
# Intern Type: Paid
# Eligible for Promotion: True
# Name: Grace
# Temporary ID: Temp_1
# Joining Date: 2003-07-01
# Intern Type: Unpaid
# Eligible for Promotion: True
# The intern is promoted!
# ...

# %% [markdown]
# LAB-08-CLASSWORK

# %%
#TASK-1-CLASSWORK

class Employee:
    def __init__(self, name, employee_id, department):
        self.name = name
        self.employee_id = employee_id
        self.department = department
        self.basic_salary = 30000
        self.salary = self.basic_salary
        self.employee_type = "Regular"

    def employeeDetails(self):
        print(f"Name: {self.name}, Dept {self.department}")
        print(f"Employee id: {self.employee_id}, Salary: {self.salary:.1f}")
        if self.employee_type == "Foreign" or self.employee_type == "Part Time" :
            print(f"Employee Type: {self.employee_type}")

    def workDistribution(self, department):
        if self.department == "HR":
            print("Collect work distribution details from the manager.")
        else:
            print("Collect work distribution loads from the HR department.")

    def increment(self):
        self.salary += self.basic_salary * 0.10


class Foreign_employee(Employee):
    def __init__(self, name, employee_id, department):
        super().__init__(name, employee_id, department)
        self.salary = self.basic_salary
        self.employee_type = "Foreign"

    def increment(self):
        self.salary += self.basic_salary * 0.15


class Part_time_employee(Employee):
    def __init__(self, name, employee_id, department):
        super().__init__(name, employee_id, department)
        self.basic_salary = 15000
        self.salary = self.basic_salary
        self.employee_type = "Part Time"


print("1------------------------------------------")
emp1 = Employee("Nawaz Ali", 102, "Marketing")
print("2------------------------------------------")
emp1.employeeDetails()
print("3------------------------------------------")
emp1.workDistribution("Marketing")
print("4------------------------------------------")
emp1.increment()
emp1.employeeDetails()
print("5------------------------------------------")
f_emp = Foreign_employee("Nadvi", 311, "Human Resource")
f_emp.employeeDetails()
print("6------------------------------------------")
f_emp.workDistribution("Human Resource")
print("7------------------------------------------")
f_emp.increment()
f_emp.employeeDetails()
print("8------------------------------------------")
p1_emp = Part_time_employee("Asif", 210, "Sales")
p2_emp = Part_time_employee("Olive", 223, "Accounts")
print("9------------------------------------------")
p1_emp.employeeDetails()
print("10------------------------------------------")
p1_emp.workDistribution("Sales")
print("11------------------------------------------")
p2_emp.increment()
print("12------------------------------------------")
p2_emp.employeeDetails()
# Out:
# 1------------------------------------------
# 2------------------------------------------
# Name: Nawaz Ali, Dept Marketing
# Employee id: 102, Salary: 30000.0
# 3------------------------------------------
# Collect work distribution loads from the HR department.
# 4------------------------------------------
# Name: Nawaz Ali, Dept Marketing
# Employee id: 102, Salary: 33000.0
# 5------------------------------------------
# Name: Nadvi, Dept Human Resource
# Employee id: 311, Salary: 30000.0
# Employee Type: Foreign
# 6------------------------------------------
# Collect work distribution loads from the HR department.
# 7------------------------------------------
# Name: Nadvi, Dept Human Resource
# Employee id: 311, Salary: 34500.0
# Employee Type: Foreign
# 8------------------------------------------
# 9------------------------------------------
# Name: Asif, Dept Sales
# Employee id: 210, Salary: 15000.0
# Employee Type: Part Time
# 10------------------------------------------
# ...

# %%
#TASK-2-CLASSWORK

class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
        self.area = 0

    def calculate_area(self):
        return self.area

    def print_details(self):
        print("--------- Printing details ----------")
        print(f'Co-ordinate: ({self.x},{self.y})')
        print(f'Area: {self.area:}')


class Circle(Point):
    def __init__(self,radius,x=0,y=0) :
        super().__init__(x, y)
        self.radius = radius
        self.area = 3.1416 * self.radius ** 2

    def print_details(self):
        super().print_details()
        print(f'Radius: {self.radius:}')


class Sphere(Circle):
    def __init__(self, x=0, y=0, radius=1):
        super().__init__(x, y, radius)
        self.area = 4 * 3.1416 * self.radius ** 2

print("--------------1---------------")
p1 = Point(2,3)
print(f'Area of p1: {p1.calculate_area()}')
print("--------------2---------------")
p1.print_details()
print("--------------3---------------")
p2 = Point()
p2.print_details()
print("--------------4---------------")
c1 = Circle(4,0,3)
print(f'Area of c1: {c1.calculate_area()}')
print("--------------5---------------")
c1.print_details()
print("--------------6---------------")
c2 = Circle(7)
print(f'Area of c2: {c2.calculate_area()}')
print("--------------7---------------")
sph1 = Sphere(3,0,2)
print(f'Area of sph1: {sph1.calculate_area()}')
print("--------------8---------------")
sph1.print_details()
print("--------------9---------------")
sph2 = Sphere(6)
print(f'Area of sph2: {sph2.calculate_area()}')
# Out:
# --------------1---------------
# Area of p1: 0
# --------------2---------------
# --------- Printing details ----------
# Co-ordinate: (2,3)
# Area: 0
# --------------3---------------
# --------- Printing details ----------
# Co-ordinate: (0,0)
# Area: 0
# --------------4---------------
# Area of c1: 50.2656
# --------------5---------------
# --------- Printing details ----------
# Co-ordinate: (0,3)
# Area: 50.2656
# Radius: 4
# --------------6---------------
# Area of c2: 153.9384
# --------------7---------------
# Area of sph1: 113.0976
# --------------8---------------
# --------- Printing details ----------
# Co-ordinate: (0,2)
# Area: 113.0976
# Radius: 3
# --------------9---------------
# Area of sph2: 452.3904

# %%
#TASK-3-CLASSWORK

class Account:
    def __init__(self, account_number, balance):
      self.account_number = account_number
      self.balance = balance
      self.account_type = "General"
      self.maturity = 0


    def print_details(self):
      print("------ Account details ------")
      print(f"Account Type: {self.account_type}, Maturity: {self.maturity} years")
      print(f"Account Number: {self.account_number}, Balance: ${self.balance:.2f}")


    def deposit(self, amount):
      self.balance += amount
      print(f"Deposited ${amount:.2f}. New Balance: ${self.balance:.2f}")


    def withdraw(self, amount):
      if self.balance >= amount:
          self.balance -= amount
          print(f"Withdrew ${amount:.2f}. New Balance: ${self.balance:.2f}")
      else:
          print("Insufficient funds.")


    def year_passed(self, year):
      self.maturity += year
      print(f"Maturity of the account: {self.maturity} years")



class SavingsAccount(Account):
    def __init__(self, account_type, account_number, balance, interest_rate, minimum_limit):
        super().__init__(account_number, balance)
        self.account_type = account_type
        self.interest_rate = interest_rate
        self.minimum_limit = minimum_limit

    def print_details(self):
        print("------ Account details ------")
        print(f"Account Type: {self.account_type}, Maturity: {self.maturity} years")
        print(f"Account Number: {self.account_number}, Balance: ${self.balance:.2f}")
        if self.account_type == "Savings":
            print(f"Interest Rate: {self.interest_rate:.2f}, Minimum Limit: ${self.minimum_limit:.2f}")

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ${amount:.2f}. New Balance: ${self.balance:.2f}")

    def withdraw(self, amount):
        if self.balance - amount >= self.minimum_limit:
            self.balance -= amount
            print(f"Withdrew ${amount:.2f}. New Balance: ${self.balance:.2f}")
        else:
            print("Insufficient funds.")

    def apply_interest(self):
        interest_amount = self.balance * self.interest_rate
        self.balance += interest_amount
        print(f"Interest applied. New Balance: ${self.balance:.2f}")


class FixedDepositAccount(Account):
    def __init__(self, account_type, account_number, balance, maturity_period):
        super().__init__(account_number, balance)
        self.account_type = account_type
        self.maturity_period = maturity_period

    def deposit(self, amount):
        print("You cannot deposit in a fixed deposit account.")

    def year_passed(self, year):
        super().year_passed(year)


    def withdraw(self, amount):
        if self.maturity >= self.maturity_period:
            super().withdraw(amount)
        else:
          super().withdraw(amount)

print("-----------1------------")
account = Account("A203", 2000)
account.print_details()
print("-----------2------------")
account.deposit(400)
account.withdraw(1500)
account.year_passed(2)
print("-----------3------------")
account.print_details()
print("-----------4------------")
savings_account = SavingsAccount("Savings", "SA123", 1000, 0.05, 500)
savings_account.print_details()
print("-----------5------------")
savings_account.deposit(400)
print("-----------6------------")
savings_account.withdraw(1000)
print("-----------7------------")
savings_account.withdraw(800)
print("-----------8------------")
savings_account.apply_interest()
print("-----------9------------")
savings_account.print_details()
print("-----------10------------")
fixed_account1 = FixedDepositAccount("Fixed Deposit", "FDA321", 10000, 5)
fixed_account1.print_details()
print("-----------11------------")
fixed_account1.deposit(400)
print("-----------12------------")
fixed_account1.year_passed(6)
print("-----------13------------")
fixed_account1.withdraw(10000)
print("-----------14------------")
fixed_account1.print_details()
print("-----------15------------")
fixed_account2 = FixedDepositAccount("Fixed Deposit", "FDA300", 50000, 7)
fixed_account2.print_details()
print("-----------16------------")
fixed_account2.withdraw(10000)
# Out:
# -----------1------------
# ------ Account details ------
# Account Type: General, Maturity: 0 years
# Account Number: A203, Balance: $2000.00
# -----------2------------
# Deposited $400.00. New Balance: $2400.00
# Withdrew $1500.00. New Balance: $900.00
# Maturity of the account: 2 years
# -----------3------------
# ------ Account details ------
# Account Type: General, Maturity: 2 years
# Account Number: A203, Balance: $900.00
# -----------4------------
# ------ Account details ------
# Account Type: Savings, Maturity: 0 years
# Account Number: SA123, Balance: $1000.00
# Interest Rate: 0.05, Minimum Limit: $500.00
# -----------5------------
# Deposited $400.00. New Balance: $1400.00
# -----------6------------
# Insufficient funds.
# -----------7------------
# Withdrew $800.00. New Balance: $600.00
# -----------8------------
# Interest applied. New Balance: $630.00
# -----------9------------
# ------ Account details ------
# Account Type: Savings, Maturity: 0 years
# ...

# %% [markdown]
# LAB-08-HOMEWORK

# %%
#TASK-1-HOMEWORK

class Fruit:
    def __init__(self, formalin=False, name=''):
        self.__formalin = formalin
        self.name = name
    def getName(self):
        return self.name
    def hasFormalin(self):
        return self.__formalin
class testFruit:
    def test(self, f):
        print('----Printing Detail----')
        if f.hasFormalin():
            print('Do not eat the',f.getName(),'.')
            print(f)
        else:
            print('Eat the',f.getName(),'.')
            print(f)

#Solution:
class Mango(Fruit):
    def __init__(self):
        super().__init__(True,"Mango")
    def __str__(self):
        return "Mangos are bad for you"
class Jackfruit(Fruit):
    def __init__(self):
        super().__init__(False,"Jackfruit")
    def __str__(self):
        return "Jackfruits are good for you"

# Execution commands
m = Mango()
j = Jackfruit()
t1 = testFruit()
t1.test(m)
t1.test(j)
# Out:
# ----Printing Detail----
# Do not eat the Mango .
# Mangos are bad for you
# ----Printing Detail----
# Eat the Jackfruit .
# Jackfruits are good for you

# %%
#TASK-2-HOMEWORK

class Exam:
    def __init__(self,marks):
        self.marks = marks
        self.time = 60
    def examSyllabus(self):
        return "Maths , English"
    def examParts(self):
        return "Part 1 - Maths\nPart 2 - English\n"

#Solution:
class  ScienceExam(Exam):
    def __init__(self,marks,time,*subjects):
        super().__init__(marks)
        self.time=time
        self.subjects = subjects[:]
        self.parts=len(subjects)+2
    def __str__(self):
        return f"Marks: {self.marks} Time: {self.time} minutes Number of Parts: {self.parts}"
    def examSyllabus(self):
        subj="Maths , English"
        for e in self.subjects:
                subj+=" , "+e
        return subj
    def examParts(self):
        subj="Part 1 - Maths\nPart 2 - English\n"
        count_s=3
        for element in self.subjects:
            if element!=self.subjects[-1]:
                subj+="Part "+str( count_s)+" - "+element+"\n"
            else:
                 subj+="Part "+str( count_s)+" - "+element
            count_s+=1
        return subj
# Execution commands
engineering = ScienceExam(100,90,"Physics","HigherMaths")
print(engineering)
print('----------------------------------')
print(engineering.examSyllabus())
print(engineering.examParts())
print('==================================')
architecture =ScienceExam(100,120,"Physics","HigherMaths","Drawing")
print(architecture)
print('----------------------------------')
print(architecture.examSyllabus())
print(architecture.examParts())
# Out:
# Marks: 100 Time: 90 minutes Number of Parts: 4
# ----------------------------------
# Maths , English , Physics , HigherMaths
# Part 1 - Maths
# Part 2 - English
# Part 3 - Physics
# Part 4 - HigherMaths
# ...
# Marks: 100 Time: 120 minutes Number of Parts: 5
# ----------------------------------
# Maths , English , Physics , HigherMaths , Drawing
# Part 1 - Maths
# Part 2 - English
# Part 3 - Physics
# Part 4 - HigherMaths
# Part 5 - Drawing

# %%
 #TASK-3-HOMEWROK

class PokemonBasic:
    def __init__(self, name = 'Default', hp = 0,weakness = 'None', type = 'Unknown'):
        self.name = name
        self.hit_point = hp
        self.weakness = weakness
        self.type = type
    def get_type(self):
        return 'Main type: ' + self.type
    def get_move(self):
        return 'Basic move: ' + 'Quick Attack'
    def __str__(self):
        return "Name: " + self.name + ", HP: " +str(self.hit_point) + ", Weakness: " + self.weakness
        print('\n------------Basic Info:--------------')

#Solution:
class PokemonExtra(PokemonBasic):
    def __init__(self,name = 'Default', hp = 0,weakness = 'None', type = 'Unknown',secondary_typ=None,other_move=None):
        super().__init__(name , hp,weakness, type )
        self.secondary_typ=secondary_typ
        self.other_move=other_move
        if secondary_typ!=None:
             super().get_type()
        if other_move!=None:
            super().get_move
    def get_type(self):
        if self.secondary_typ!=None:
            return f'Main type:{self.type},Secondary type:{self.secondary_typ}'
        else:
            return 'Main type: ' + self.type
    def get_move(self):
        if self.other_move!=None:
            m,n=self.other_move
            return f'Basic move:Quick Attack \nOther move:{m},{n}'
        else:
            return 'Basic move: ' + 'Quick Attack'

# Execution commands
print('\n------------Basic Info:--------------')
pk = PokemonBasic()
print(pk)
print(pk.get_type())
print(pk.get_move())
print('\n------------Pokemon 1 Info:-------------')
charmander = PokemonExtra('Charmander', 39, 'Water','Fire')
print(charmander)
print(charmander.get_type())
print(charmander.get_move())
print('\n------------Pokemon 2 Info:-------------')
charizard = PokemonExtra('Charizard', 78, 'Water','Fire', 'Flying', ('Fire Spin', 'Fire Blaze'))
print(charizard)
print(charizard.get_type())
print(charizard.get_move())
# Out:
# ------------Basic Info:--------------
# Name: Default, HP: 0, Weakness: None
# Main type: Unknown
# Basic move: Quick Attack
#
# ------------Pokemon 1 Info:-------------
# Name: Charmander, HP: 39, Weakness: Water
# Main type: Fire
# Basic move: Quick Attack
#
# ------------Pokemon 2 Info:-------------
# Name: Charizard, HP: 78, Weakness: Water
# Main type:Fire,Secondary type:Flying
# Basic move:Quick Attack
# Other move:Fire Spin,Fire Blaze

# %%
#TASK-4-CLASSWORK

class Cakes:
    order_list = {}
    feedbacks = {}
    def __init__(self,flavor,weight,sweetness="Moderate",cream_type="Whipped Cream"):
        self.flavor = flavor
        self.weight = weight
        self.sweetness = sweetness
        self.cream_type = cream_type
        self.price = weight*1.2
        if f"{flavor} Cake {weight}gm" not in Cakes.order_list:
            Cakes.order_list[f"{flavor} Cake {weight}gm"] = 1
        else:
            Cakes.order_list[f"{flavor} Cake {weight}gm"] += 1

    def add_customization(self, sweetness=None, cream_type=None):
       if sweetness is not None:
        self.sweetness = sweetness
       if cream_type is not None:
        self.cream_type = cream_type


    def cake_details(self):
        print(f"Flavor: {self.flavor} Cake, Weight: {self.weight} gm")
        print(f"Sweetness: {self.sweetness} sugar, Cream Type: {self.cream_type}")
        print(f"Price: {self.price} Taka")

    @classmethod
    def give_feedbacks(cls,cake,feedback):
        if cake not in cls.feedbacks:
            cls.feedbacks[cake] = [feedback]
        else:
            cls.feedbacks[cake].append(feedback)
        print("Thanks for your valuable feedback!")

    @classmethod
    def show_feedbacks(cls):
        print(cls.feedbacks)

class Cheese_Cakes(Cakes):
    def __init__(self,flavor,weight,cake_type="baked",sweetness="Moderate",cream_type="Cream Cheese"):
        super().__init__(flavor,weight,sweetness,cream_type)
        self.cake_type = cake_type
        self.price = weight*1.5
        if f"{flavor} Cheese Cake {weight}gm" not in Cakes.order_list:
            Cakes.order_list[f"{flavor} Cheese Cake {weight}gm"] = 1
        else:
            Cakes.order_list[f"{flavor} Cheese Cake {weight}gm"] += 1

    def add_customization(self,sweetness=None,cream_type=None):
        print("Sorry! No customization available for cheese cakes.")

    def cake_details(self):
        print(f"Flavor: {self.flavor} Cheese Cake, Weight: {self.weight} gm")
        print(f"Sweetness: {self.sweetness} sugar, Cream Type: {self.cream_type}")
        print(f"Cake Type:{self.cake_type}, Price: {self.price} Taka")

    @classmethod
    def give_feedbacks(cls,cake,feedback):
        super().give_feedbacks(cake,feedback)
        print("You will get 10% discount for your next purchase!")

#driver_code
order_1=Cakes("Chocolate",500)
order_2=Cakes("Vanilla",800)
print("(1)**********************************")
order_1.cake_details()
print("(1.1)**********************************")
print(Cakes.order_list)
print("(2)**********************************")
order_2.add_customization("Zero","Butter Cream")
order_2.cake_details()
print("(3)**********************************")
Cakes.give_feedbacks("Chocolate Cake","Very Delicious")
Cakes.give_feedbacks("Chocolate Cake","Yummy")
print("(4)**********************************")
Cakes.show_feedbacks()
print("(5)**********************************")
ch_order1=Cheese_Cakes("Red velvet",700)
ch_order1.cake_details()
print("(6)**********************************")
ch_order1.add_customization()
print("(7)**********************************")
ch_order2=Cheese_Cakes("Blue Berry",900,"No Bake")
ch_order2.cake_details()
print("(8)**********************************")
print(Cakes.order_list)
print("(9)**********************************")
Cheese_Cakes.give_feedbacks("Red velvet Cheese Cake","Average")
Cheese_Cakes.give_feedbacks("Blue Berry Cheese Cake","Liked it")
print("(10)**********************************")
Cakes.show_feedbacks()
# Out:
# (1)**********************************
# Flavor: Chocolate Cake, Weight: 500 gm
# Sweetness: Moderate sugar, Cream Type: Whipped Cream
# Price: 600.0 Taka
# (1.1)**********************************
# {'Chocolate Cake 500gm': 1, 'Vanilla Cake 800gm': 1}
# (2)**********************************
# Flavor: Vanilla Cake, Weight: 800 gm
# Sweetness: Zero sugar, Cream Type: Butter Cream
# Price: 960.0 Taka
# (3)**********************************
# Thanks for your valuable feedback!
# Thanks for your valuable feedback!
# (4)**********************************
# {'Chocolate Cake': ['Very Delicious', 'Yummy']}
# (5)**********************************
# Flavor: Red velvet Cheese Cake, Weight: 700 gm
# Sweetness: Moderate sugar, Cream Type: Cream Cheese
# Cake Type:baked, Price: 1050.0 Taka
# (6)**********************************
# Sorry! No customization available for cheese cakes.
# (7)**********************************
# Flavor: Blue Berry Cheese Cake, Weight: 900 gm
# ...
