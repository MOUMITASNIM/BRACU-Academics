# %%
#task_1

a_tuple = ("The Institute", ("Best Mystery & Thriller", "The Silent Patient", 68821), 75717,
[1, 2, 3, 400, 5, 6, 7], ("Best Fiction", "The Testaments", 98291))

(a_tuple[3][3])
# Out:
# 400

# %%
#task_2
a_tuple=(-10, 20, 25, 30, 40)
print(a_tuple[2:-2])
# Out:
# (25,)

# %%
#task_3
book_info = (("Best Mystery & Thriller","The Silent Patient",68,821),
("Best Horror","The Institute",75,717),
("Best History & Biography","The five",31,783 ),
("Best Fiction","The Testaments",98,291))

print("Size of the tuple is:",len(book_info))
for i in book_info:
    print(i)
# Out:
# Size of the tuple is: 4
# ('Best Mystery & Thriller', 'The Silent Patient', 68, 821)
# ('Best Horror', 'The Institute', 75, 717)
# ('Best History & Biography', 'The five', 31, 783)
# ('Best Fiction', 'The Testaments', 98, 291)

# %%
#task_4
book_info = (("Best Mystery & Thriller","The Silent Patient",68821),
("Best Horror","The Institute",75717),
("Best History & Biography","The five",31783 ),
("Best Fiction","The Testaments",98291))
for info in book_info :
    category,name,vote_amount=info
    print(name,"won the","'"+category+"'","category with",vote_amount,"votes")
# Out:
# The Silent Patient won the 'Best Mystery & Thriller' category with 68821 votes
# The Institute won the 'Best Horror' category with 75717 votes
# The five won the 'Best History & Biography' category with 31783 votes
# The Testaments won the 'Best Fiction' category with 98291 votes

# %%
#task_5
a_tuple=(10, 8, 5, 2, 10, 15, 10, 8, 5, 8, 8, 2)
num=int(input(""))
count=0
for i in a_tuple:
    if i == num:
        count=count+1
print(num , "appears", count , "times in the tuple")
# Out:
# 8
# 8 appears 4 times in the tuple

# %%
#task_6
given_tuple=('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h')
list_1=list(given_tuple)
new_list=list_1[::-1]
last_tuple=tuple(new_list)
print(last_tuple)
# Out:
# ('h', 'g', 'f', 'e', 'd', 'c', 'b', 'a')

# %%
#task_7
dict1={'Harry':15, 'Draco':8, 'Nevil':19}
dict2={'Ginie':18, 'Luna': 14}
dict1.update(dict2)
dict3=dict1
print(dict3)
# Out:
# {'Harry': 15, 'Draco': 8, 'Nevil': 19, 'Ginie': 18, 'Luna': 14}

# %%
#task_8
dict1={'Jon': 100, 'Dan':200, 'Rob':300}
sum=0
count=0
for i,j in dict1.items():
    sum+=1
    count+=j

print("Average is",count/sum)
# Out:
# Average is 200.0

# %%
#task_9
exam_marks={'Cierra Vega': 175, 'Alden Cantrell': 200, 'Kierra Gentry': 165, 'Pierre Cox': 190}
dict1={}
num=int(input("Enter a number:"))
for i in exam_marks.keys():
    if num <= exam_marks[i]:
        dict1[i] = exam_marks[i]
print(dict1)
# Out:
# Enter a number :190
# {'Alden Cantrell': 200, 'Pierre Cox': 190}

# %%
#task_10
book_shop = {'sci fi': 12, 'mystery': 15, 'horror': 8, 'mythology': 10, 'young_adult': 4, 'adventure':14}
max=1
for i in book_shop.values():
    if i>max:
        max=i
for j,k in book_shop.items():
    if k==max:
     print('The highest selling book genre is'"'"+j+"'"'and the number of books sold are',k)
# Out:
# The highest selling book genre is'mystery'and the number of books sold are 15

# %%
#task_11
str_1 = input("").lower().replace(" ","")
dict_1 = {}
for i in str_1:
  if i in dict_1:
    dict_1[i] = dict_1[i]+1
  else:
    dict_1[i] = 1

print(dict_1)
# Out:
# "Python programming is fun"
# {'"': 2, 'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 3, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 2, 's': 1, 'f': 1, 'u': 1}

# %%
#task_12
dict_1 = {'A': [1,2,3], 'b': ['1', '2'], "c": [4, 5, 6, 7]}
count = 0
for i in  dict_1:
  for j in dict_1[i]:
    count = count + 1
print(count)
# Out:
# 9

# %%
#task_13
list_1 = [("a", 1), ("b", 2), ("a", 3), ("b", 1), ("a", 2), ("c", 1)]
d={}
for i in list_1:
  d[i[0]]=[]
for i in list_1:
  d[i[0]].append(i[1])
print(d)
# Out:
# {'a': [1, 3, 2], 'b': [2, 1], 'c': [1]}

# %%
#task_7
d1={'Harry':15, 'Draco':8, 'Nevil':19}
d2={'Ginie':18, 'Luna': 14}
d3={}
for i in d1:
  d3[i]=d1[i]
for i in d2:
  d3[i]=d2[i]

print(d3)
# Out:
# {'Harry': 15, 'Draco': 8, 'Nevil': 19, 'Ginie': 18, 'Luna': 14}
