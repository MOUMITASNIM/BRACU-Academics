# %%
#task_1
S1=input()
S2= S1[::-1]
print(S2)
# Out:
# Python
# nohtyP

# %%
#task_2
s=input( )
n=int(input("Enter a number:"))
s1=s[n: : -1]
print(s1+s[n+1:len(s)+1:1])
# Out:
# 72418
# Enter a number:4
# 81427

# %%
#task_3
input_str = input("Enter a string: ")
bin = True
for count in input_str:
    if i=="0" or i=="1":
        bin = True
    else:
        bin = False
        break
if bin == True:
    print("Binary Number")
else:
    print("Not a Binary Number")
# Out:
# Please input a string: 01101101101
# Binary Number

# %%
#task_4
str_1 = input("Enter a string: ")
if str_1.endswith("er"):
    print(str_1.replace("er", "est"))
elif str_1.endswith("est"):
    print(str_1)
elif len(str_1)<4:
    print(str_1)
elif len(str_1)>3:
    s+="er"
    print(str_1)
# Out:
# Enter a string: ber
# best

# %%
#task_5
s = input("Enter a string: ")
for count in range(0, len(s)):
    print(s[0:count+1:1])
# Out:
# Enter a string: BANGLA
# B
# BA
# BAN
# BANG
# BANGL
# BANGLA

# %%
#task_6
a=input("Enter:")
for i in range(len(a)):
    l=a[i]
    print(l,":", ord(l))
# Out:
# Enter:Programming
# P : 80
# r : 114
# o : 111
# g : 103
# r : 114
# a : 97
# m : 109
# m : 109
# i : 105
# n : 110
# g : 103

# %%
#task_7
s = input("Enter a string: ")
for i in s:
    if i == "z":
        print("a", end= "")
    else:
        print(chr(ord(i)+1), end= "")
# Out:
# Enter a string: xyzabc
# yzabcd

# %%
#task_8
s=input("Enter a string:")
for i in range(len(s)):
  if(i%2!=0):
    print(chr(ord(s[i])-32),end="")
# Out:
# Enter a string:abcd
# BD

# %%
#task_9
str_1 = input("Enter a string: ")
current = " "
new = ""
for i in range(0,len(str_1)):
    if str_1[i]!= current[i]:
        new+=str_1[i]
    current += str_1[i]
print(new)
# Out:
# Enter a string: Jupyter Notebook is better. Case sensitivity check AAaaaAaaAAAa.
# Jupyter Notebok is beter. Case sensitivity check AaAaAa.

# %%
#task_10
s = input("Enter:")
count = 0
for i in s:
    if i=="," :
     break
    count+=1
print(count)
s1=s[0:count]
s2=s[count+2:]
print(s1,s2)
x=0 #x
y=0 #y
s_out=""
while(x<=len(s1) or y<=len(s2)) :
  if(x<len(s1)):
    s_out+=s1[x]
  if(y<len(s2)):
    s_out+=s2[y]
  x+=1
  y+=1
print(s_out)
# Out:
# Enter:ABCD, efgh
# 4
# ABCD efgh
# AeBfCgDh
